# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다. (이미지를 생성 할 때 마다 저장하기)
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7101  g_loss:0.6986
# epoch:1  d_loss:0.4348  g_loss:0.3323
# epoch:2  d_loss:0.5332  g_loss:0.1001
# epoch:3  d_loss:0.7526  g_loss:0.0611
# epoch:4  d_loss:0.6900  g_loss:0.1292
# epoch:5  d_loss:0.5406  g_loss:0.3777
# epoch:6  d_loss:0.4938  g_loss:0.7602
# epoch:7  d_loss:0.5136  g_loss:0.9300
# epoch:8  d_loss:0.5171  g_loss:1.0347
# epoch:9  d_loss:0.4714  g_loss:0.9863
# epoch:10  d_loss:0.4006  g_loss:0.9849
# epoch:11  d_loss:0.3568  g_loss:0.9781
# epoch:12  d_loss:0.3677  g_loss:0.9458
# epoch:13  d_loss:0.2806  g_loss:0.9013
# epoch:14  d_loss:0.4322  g_loss:0.8271
# epoch:15  d_loss:0.5132  g_loss:0.6806
# epoch:16  d_loss:0.5493  g_loss:1.1375
# epoch:17  d_loss:0.6562  g_loss:0.9594
# epoch:18  d_loss:0.7134  g_loss:0.6270
# epoch:19  d_loss:0.5503  g_loss:0.7971
# epoch:20  d_loss:0.6358  g_loss:0.7492
# epoch:21  d_loss:0.6355  g_loss:0.8656
# epoch:22  d_loss:0.6083  g_loss:0.8732
# epoch:23  d_loss:0.5005  g_loss:0.8069
# epoch:24  d_loss:0.5283  g_loss:0.7912
# epoch:25  d_loss:0.5258  g_loss:0.7577
# epoch:26  d_loss:0.5083  g_loss:0.7882
# epoch:27  d_loss:0.5497  g_loss:0.6706
# epoch:28  d_loss:0.5174  g_loss:0.6897
# epoch:29  d_loss:0.5587  g_loss:0.6927
# epoch:30  d_loss:0.4896  g_loss:0.6436
# epoch:31  d_loss:0.4926  g_loss:0.7975
# epoch:32  d_loss:0.4992  g_loss:0.7028
# epoch:33  d_loss:0.4541  g_loss:0.8673
# epoch:34  d_loss:0.4008  g_loss:0.9320
# epoch:35  d_loss:0.4549  g_loss:0.9125
# epoch:36  d_loss:0.4335  g_loss:0.9258
# epoch:37  d_loss:0.4151  g_loss:0.8768
# epoch:38  d_loss:0.4086  g_loss:1.1242
# epoch:39  d_loss:0.2992  g_loss:1.0171
# epoch:40  d_loss:0.3194  g_loss:1.2109
# epoch:41  d_loss:0.3840  g_loss:1.2791
# epoch:42  d_loss:0.3586  g_loss:1.2597
# epoch:43  d_loss:0.2954  g_loss:1.4379
# epoch:44  d_loss:0.2129  g_loss:1.6889
# epoch:45  d_loss:0.2337  g_loss:2.0491
# epoch:46  d_loss:0.2645  g_loss:2.1321
# epoch:47  d_loss:0.1732  g_loss:2.3032
# epoch:48  d_loss:0.1802  g_loss:2.2677
# epoch:49  d_loss:0.1857  g_loss:2.7232
# epoch:50  d_loss:0.1403  g_loss:3.1566
# epoch:51  d_loss:0.1821  g_loss:2.9564
# epoch:52  d_loss:0.1959  g_loss:2.5984
# epoch:53  d_loss:0.2121  g_loss:2.5552
# epoch:54  d_loss:0.2311  g_loss:2.6558
# epoch:55  d_loss:0.3666  g_loss:2.5650
# epoch:56  d_loss:0.6345  g_loss:2.1032
# epoch:57  d_loss:0.2550  g_loss:2.2215
# epoch:58  d_loss:0.1607  g_loss:2.8176
# epoch:59  d_loss:0.1072  g_loss:3.3156
# epoch:60  d_loss:0.1051  g_loss:2.5808
# epoch:61  d_loss:0.0911  g_loss:2.4999
# epoch:62  d_loss:0.0846  g_loss:2.8907
# epoch:63  d_loss:0.1622  g_loss:3.3497
# epoch:64  d_loss:0.1869  g_loss:2.9805
# epoch:65  d_loss:0.5538  g_loss:2.6622
# epoch:66  d_loss:0.5617  g_loss:2.6644
# epoch:67  d_loss:0.4968  g_loss:4.0116
# epoch:68  d_loss:1.3243  g_loss:2.6878
# epoch:69  d_loss:0.8802  g_loss:2.0479
# epoch:70  d_loss:0.6561  g_loss:2.4242
# epoch:71  d_loss:0.4599  g_loss:3.9641
# epoch:72  d_loss:0.4700  g_loss:3.3523
# epoch:73  d_loss:0.3374  g_loss:3.1576
# epoch:74  d_loss:0.3388  g_loss:3.1685
# epoch:75  d_loss:0.3602  g_loss:3.2281
# epoch:76  d_loss:0.4049  g_loss:2.3850
# epoch:77  d_loss:0.4094  g_loss:2.2988
# epoch:78  d_loss:0.4293  g_loss:2.0476
# epoch:79  d_loss:0.4929  g_loss:1.8316
# epoch:80  d_loss:0.5492  g_loss:1.4612
# epoch:81  d_loss:0.6127  g_loss:1.5250
# epoch:82  d_loss:0.4612  g_loss:1.5696
# epoch:83  d_loss:0.6633  g_loss:1.2736
# epoch:84  d_loss:0.6839  g_loss:1.1997
# epoch:85  d_loss:0.5764  g_loss:1.3956
# epoch:86  d_loss:0.5508  g_loss:1.9539
# epoch:87  d_loss:0.4924  g_loss:1.9526
# epoch:88  d_loss:0.4818  g_loss:2.0848
# epoch:89  d_loss:0.4201  g_loss:2.3363
# epoch:90  d_loss:0.1939  g_loss:3.0738
# epoch:91  d_loss:0.2042  g_loss:3.8895
# epoch:92  d_loss:0.3016  g_loss:3.2853
# epoch:93  d_loss:0.2336  g_loss:3.0956
# epoch:94  d_loss:0.3126  g_loss:2.8640
# epoch:95  d_loss:0.3506  g_loss:2.9945
# epoch:96  d_loss:0.4272  g_loss:3.9867
# epoch:97  d_loss:0.7451  g_loss:3.0479
# epoch:98  d_loss:0.8049  g_loss:2.3874
# epoch:99  d_loss:0.7386  g_loss:2.6187
# epoch:100  d_loss:0.8269  g_loss:2.6897
# epoch:101  d_loss:0.8923  g_loss:2.9616
# epoch:102  d_loss:0.6944  g_loss:2.7429
# epoch:103  d_loss:0.8307  g_loss:1.9638
# epoch:104  d_loss:0.8631  g_loss:1.4118
# epoch:105  d_loss:0.6794  g_loss:1.4000
# epoch:106  d_loss:0.6121  g_loss:1.4309
# epoch:107  d_loss:0.4945  g_loss:1.6403
# epoch:108  d_loss:0.5000  g_loss:1.7636
# epoch:109  d_loss:0.5316  g_loss:1.7823
# epoch:110  d_loss:0.4791  g_loss:1.6871
# epoch:111  d_loss:0.5399  g_loss:1.2262
# epoch:112  d_loss:0.4279  g_loss:1.2860
# epoch:113  d_loss:0.5160  g_loss:1.2779
# epoch:114  d_loss:0.5216  g_loss:1.1491
# epoch:115  d_loss:0.4783  g_loss:0.9669
# epoch:116  d_loss:0.4747  g_loss:1.3834
# epoch:117  d_loss:0.5164  g_loss:1.4093
# epoch:118  d_loss:0.4564  g_loss:1.1820
# epoch:119  d_loss:0.3819  g_loss:1.1599
# epoch:120  d_loss:0.5536  g_loss:1.1264
# epoch:121  d_loss:0.5362  g_loss:1.0769
# epoch:122  d_loss:0.7129  g_loss:0.9162
# epoch:123  d_loss:0.5462  g_loss:0.9644
# epoch:124  d_loss:0.4231  g_loss:1.1200
# epoch:125  d_loss:0.6324  g_loss:0.9363
# epoch:126  d_loss:0.5415  g_loss:1.1752
# epoch:127  d_loss:0.6050  g_loss:1.1146
# epoch:128  d_loss:0.5533  g_loss:1.1136
# epoch:129  d_loss:0.5638  g_loss:1.1716
# epoch:130  d_loss:0.5210  g_loss:1.2086
# epoch:131  d_loss:0.4832  g_loss:1.3174
# epoch:132  d_loss:0.5246  g_loss:1.1059
# epoch:133  d_loss:0.5286  g_loss:1.2307
# epoch:134  d_loss:0.5329  g_loss:0.9735
# epoch:135  d_loss:0.5458  g_loss:1.1376
# epoch:136  d_loss:0.4886  g_loss:1.4038
# epoch:137  d_loss:0.4203  g_loss:1.5041
# epoch:138  d_loss:0.4689  g_loss:1.7420
# epoch:139  d_loss:0.4694  g_loss:1.5627
# epoch:140  d_loss:0.4730  g_loss:1.5209
# epoch:141  d_loss:0.4966  g_loss:1.5627
# epoch:142  d_loss:0.4098  g_loss:1.6333
# epoch:143  d_loss:0.5230  g_loss:1.5177
# epoch:144  d_loss:0.4487  g_loss:1.7304
# epoch:145  d_loss:0.3828  g_loss:1.7053
# epoch:146  d_loss:0.3521  g_loss:1.9739
# epoch:147  d_loss:0.4510  g_loss:1.7007
# epoch:148  d_loss:0.6530  g_loss:1.2182
# epoch:149  d_loss:0.4527  g_loss:1.5574
# epoch:150  d_loss:0.4700  g_loss:1.5311
# epoch:151  d_loss:0.4638  g_loss:2.0272
# epoch:152  d_loss:0.5480  g_loss:1.9883
# epoch:153  d_loss:0.5441  g_loss:1.8333
# epoch:154  d_loss:0.4669  g_loss:1.5705
# epoch:155  d_loss:0.4960  g_loss:1.2990
# epoch:156  d_loss:0.5117  g_loss:1.3082
# epoch:157  d_loss:0.4388  g_loss:1.6705
# epoch:158  d_loss:0.5087  g_loss:1.5896
# epoch:159  d_loss:0.3834  g_loss:1.8839
# epoch:160  d_loss:0.4680  g_loss:1.9880
# epoch:161  d_loss:0.4569  g_loss:1.8682
# epoch:162  d_loss:0.4433  g_loss:1.9371
# epoch:163  d_loss:0.4935  g_loss:1.7523
# epoch:164  d_loss:0.3988  g_loss:1.5518
# epoch:165  d_loss:0.3952  g_loss:1.5005
# epoch:166  d_loss:0.4730  g_loss:1.6667
# epoch:167  d_loss:0.4234  g_loss:1.6944
# epoch:168  d_loss:0.3576  g_loss:2.0210
# epoch:169  d_loss:0.4362  g_loss:2.0888
# epoch:170  d_loss:0.4862  g_loss:1.7463
# epoch:171  d_loss:0.3985  g_loss:1.7817
# epoch:172  d_loss:0.3948  g_loss:1.5349
# epoch:173  d_loss:0.3558  g_loss:1.8539
# epoch:174  d_loss:0.4061  g_loss:1.7441
# epoch:175  d_loss:0.3371  g_loss:1.8626
# epoch:176  d_loss:0.4417  g_loss:1.8370
# epoch:177  d_loss:0.5066  g_loss:1.7507
# epoch:178  d_loss:0.3530  g_loss:1.7809
# epoch:179  d_loss:0.5069  g_loss:1.6886
# epoch:180  d_loss:0.5211  g_loss:1.4340
# epoch:181  d_loss:0.3500  g_loss:1.9633
# epoch:182  d_loss:0.4184  g_loss:2.1075
# epoch:183  d_loss:0.4361  g_loss:1.7623
# epoch:184  d_loss:0.4609  g_loss:1.4906
# epoch:185  d_loss:0.4795  g_loss:1.8606
# epoch:186  d_loss:0.4793  g_loss:1.5195
# epoch:187  d_loss:0.5381  g_loss:1.3643
# epoch:188  d_loss:0.6177  g_loss:1.3625
# epoch:189  d_loss:0.4637  g_loss:1.5764
# epoch:190  d_loss:0.4224  g_loss:1.6979
# epoch:191  d_loss:0.5082  g_loss:1.4673
# epoch:192  d_loss:0.4191  g_loss:1.9144
# epoch:193  d_loss:0.4829  g_loss:1.7104
# epoch:194  d_loss:0.5730  g_loss:1.3834
# epoch:195  d_loss:0.4788  g_loss:1.4562
# epoch:196  d_loss:0.4230  g_loss:1.6893
# epoch:197  d_loss:0.5470  g_loss:1.7690
# epoch:198  d_loss:0.6082  g_loss:1.6508
# epoch:199  d_loss:0.4954  g_loss:1.7604
# epoch:200  d_loss:0.6700  g_loss:1.5292
# epoch:201  d_loss:0.7016  g_loss:1.8097
# epoch:202  d_loss:0.5170  g_loss:1.7146
# epoch:203  d_loss:0.3877  g_loss:1.8057
# epoch:204  d_loss:0.3659  g_loss:1.8382
# epoch:205  d_loss:0.4335  g_loss:1.9323
# epoch:206  d_loss:0.4016  g_loss:1.9957
# epoch:207  d_loss:0.4534  g_loss:1.7417
# epoch:208  d_loss:0.4842  g_loss:1.9819
# epoch:209  d_loss:0.4537  g_loss:2.4148
# epoch:210  d_loss:0.4209  g_loss:2.7010
# epoch:211  d_loss:0.4199  g_loss:2.2708
# epoch:212  d_loss:0.4943  g_loss:1.9082
# epoch:213  d_loss:0.6050  g_loss:1.7624
# epoch:214  d_loss:0.6490  g_loss:1.8864
# epoch:215  d_loss:0.5611  g_loss:2.0527
# epoch:216  d_loss:0.4880  g_loss:2.2177
# epoch:217  d_loss:0.4969  g_loss:2.0057
# epoch:218  d_loss:0.5810  g_loss:1.7274
# epoch:219  d_loss:0.5147  g_loss:1.4364
# epoch:220  d_loss:0.5471  g_loss:1.3697
# epoch:221  d_loss:0.5885  g_loss:1.5671
# epoch:222  d_loss:0.3950  g_loss:1.8200
# epoch:223  d_loss:0.4117  g_loss:2.0128
# epoch:224  d_loss:0.4791  g_loss:2.0516
# epoch:225  d_loss:0.4704  g_loss:2.0154
# epoch:226  d_loss:0.3696  g_loss:2.4215
# epoch:227  d_loss:0.4548  g_loss:2.2646
# epoch:228  d_loss:0.5608  g_loss:1.9813
# epoch:229  d_loss:0.4630  g_loss:1.9142
# epoch:230  d_loss:0.4628  g_loss:2.2256
# epoch:231  d_loss:0.3474  g_loss:2.8374
# epoch:232  d_loss:0.3829  g_loss:3.0948
# epoch:233  d_loss:0.3296  g_loss:2.9224
# epoch:234  d_loss:0.5013  g_loss:2.3107
# epoch:235  d_loss:0.2535  g_loss:2.4154
# epoch:236  d_loss:0.2928  g_loss:2.2937
# epoch:237  d_loss:0.3754  g_loss:2.3431
# epoch:238  d_loss:0.3668  g_loss:2.8593
# epoch:239  d_loss:0.3435  g_loss:2.7437
# epoch:240  d_loss:0.3597  g_loss:2.8983
# epoch:241  d_loss:0.4081  g_loss:2.8899
# epoch:242  d_loss:0.5499  g_loss:2.3706
# epoch:243  d_loss:0.2962  g_loss:2.7203
# epoch:244  d_loss:0.4583  g_loss:2.4382
# epoch:245  d_loss:0.4232  g_loss:2.7589
# epoch:246  d_loss:0.4739  g_loss:1.7054
# epoch:247  d_loss:0.4046  g_loss:2.1734
# epoch:248  d_loss:0.4461  g_loss:2.5625
# epoch:249  d_loss:0.4283  g_loss:2.2283
# epoch:250  d_loss:0.4769  g_loss:2.6578
# epoch:251  d_loss:0.3887  g_loss:2.2409
# epoch:252  d_loss:0.3954  g_loss:1.8674
# epoch:253  d_loss:0.5386  g_loss:1.8281
# epoch:254  d_loss:0.4821  g_loss:2.1921
# epoch:255  d_loss:0.4492  g_loss:2.5462
# epoch:256  d_loss:0.4060  g_loss:2.5451
# epoch:257  d_loss:0.4202  g_loss:2.6490
# epoch:258  d_loss:0.4440  g_loss:2.3164
# epoch:259  d_loss:0.5477  g_loss:1.8996
# epoch:260  d_loss:0.3298  g_loss:1.7379
# epoch:261  d_loss:0.4611  g_loss:2.5396
# epoch:262  d_loss:0.4315  g_loss:2.3058
# epoch:263  d_loss:0.5331  g_loss:2.2634
# epoch:264  d_loss:0.5705  g_loss:1.9362
# epoch:265  d_loss:0.3852  g_loss:1.7502
# epoch:266  d_loss:0.3911  g_loss:2.1106
# epoch:267  d_loss:0.4406  g_loss:2.0576
# epoch:268  d_loss:0.4888  g_loss:2.1824
# epoch:269  d_loss:0.4607  g_loss:2.0097
# epoch:270  d_loss:0.5639  g_loss:1.6663
# epoch:271  d_loss:0.3733  g_loss:1.8302
# epoch:272  d_loss:0.4595  g_loss:1.6986
# epoch:273  d_loss:0.6216  g_loss:1.5291
# epoch:274  d_loss:0.5158  g_loss:1.8783
# epoch:275  d_loss:0.4736  g_loss:2.0583
# epoch:276  d_loss:0.6517  g_loss:2.3379
# epoch:277  d_loss:0.5881  g_loss:1.9526
# epoch:278  d_loss:0.5022  g_loss:1.4663
# epoch:279  d_loss:0.4732  g_loss:1.6445
# epoch:280  d_loss:0.4183  g_loss:2.1566
# epoch:281  d_loss:0.4579  g_loss:2.2284
# epoch:282  d_loss:0.5045  g_loss:2.4600
# epoch:283  d_loss:0.4896  g_loss:2.1861
# epoch:284  d_loss:0.4602  g_loss:1.7673
# epoch:285  d_loss:0.4722  g_loss:2.0470
# epoch:286  d_loss:0.4580  g_loss:1.9963
# epoch:287  d_loss:0.3944  g_loss:2.4698
# epoch:288  d_loss:0.3283  g_loss:2.8382
# epoch:289  d_loss:0.5061  g_loss:2.5315
# epoch:290  d_loss:0.6430  g_loss:1.5227
# epoch:291  d_loss:0.4919  g_loss:1.5766
# epoch:292  d_loss:0.3725  g_loss:1.9536
# epoch:293  d_loss:0.4206  g_loss:1.8733
# epoch:294  d_loss:0.3664  g_loss:2.1943
# epoch:295  d_loss:0.4704  g_loss:2.4328
# epoch:296  d_loss:0.4718  g_loss:2.4758
# epoch:297  d_loss:0.3807  g_loss:2.3814
# epoch:298  d_loss:0.3539  g_loss:1.9198
# epoch:299  d_loss:0.4862  g_loss:1.9048
# epoch:300  d_loss:0.4354  g_loss:1.8710
# epoch:301  d_loss:0.4203  g_loss:2.1946
# epoch:302  d_loss:0.3421  g_loss:2.9341
# epoch:303  d_loss:0.4835  g_loss:2.4448
# epoch:304  d_loss:0.3487  g_loss:2.7151
# epoch:305  d_loss:0.3959  g_loss:2.4099
# epoch:306  d_loss:0.4223  g_loss:2.0706
# epoch:307  d_loss:0.3473  g_loss:2.3469
# epoch:308  d_loss:0.3584  g_loss:2.6029
# epoch:309  d_loss:0.3520  g_loss:2.5586
# epoch:310  d_loss:0.4711  g_loss:2.2235
# epoch:311  d_loss:0.3970  g_loss:1.9679
# epoch:312  d_loss:0.3663  g_loss:1.9848
# epoch:313  d_loss:0.3894  g_loss:2.5336
# epoch:314  d_loss:0.4043  g_loss:2.5734
# epoch:315  d_loss:0.2995  g_loss:3.0519
# epoch:316  d_loss:0.3058  g_loss:2.7477
# epoch:317  d_loss:0.3491  g_loss:2.4201
# epoch:318  d_loss:0.4123  g_loss:2.2262
# epoch:319  d_loss:0.4307  g_loss:1.7801
# epoch:320  d_loss:0.4003  g_loss:2.2203
# epoch:321  d_loss:0.3917  g_loss:2.7705
# epoch:322  d_loss:0.3954  g_loss:2.8201
# epoch:323  d_loss:0.5392  g_loss:1.9305
# epoch:324  d_loss:0.3981  g_loss:2.2937
# epoch:325  d_loss:0.1997  g_loss:2.4387
# epoch:326  d_loss:0.3610  g_loss:2.5670
# epoch:327  d_loss:0.4522  g_loss:2.3654
# epoch:328  d_loss:0.4024  g_loss:2.7387
# epoch:329  d_loss:0.3968  g_loss:2.4501
# epoch:330  d_loss:0.3356  g_loss:2.3734
# epoch:331  d_loss:0.4696  g_loss:2.1974
# epoch:332  d_loss:0.4632  g_loss:1.9219
# epoch:333  d_loss:0.3144  g_loss:2.2243
# epoch:334  d_loss:0.3182  g_loss:2.4556
# epoch:335  d_loss:0.2696  g_loss:2.7345
# epoch:336  d_loss:0.3060  g_loss:2.6875
# epoch:337  d_loss:0.2767  g_loss:2.7648
# epoch:338  d_loss:0.3330  g_loss:2.4650
# epoch:339  d_loss:0.4077  g_loss:2.6410
# epoch:340  d_loss:0.2897  g_loss:2.5921
# epoch:341  d_loss:0.3548  g_loss:2.6377
# epoch:342  d_loss:0.3994  g_loss:2.5563
# epoch:343  d_loss:0.3382  g_loss:2.5384
# epoch:344  d_loss:0.2969  g_loss:2.8417
# epoch:345  d_loss:0.2728  g_loss:2.3143
# epoch:346  d_loss:0.6282  g_loss:2.0463
# epoch:347  d_loss:0.3901  g_loss:2.4193
# epoch:348  d_loss:0.3029  g_loss:2.6397
# epoch:349  d_loss:0.2945  g_loss:2.5307
# epoch:350  d_loss:0.3759  g_loss:2.2697
# epoch:351  d_loss:0.4854  g_loss:1.9683
# epoch:352  d_loss:0.4797  g_loss:2.1715
# epoch:353  d_loss:0.3865  g_loss:1.9294
# epoch:354  d_loss:0.5444  g_loss:2.2009
# epoch:355  d_loss:0.4374  g_loss:2.0978
# epoch:356  d_loss:0.4309  g_loss:2.0394
# epoch:357  d_loss:0.5557  g_loss:1.7558
# epoch:358  d_loss:0.5127  g_loss:1.6258
# epoch:359  d_loss:0.4769  g_loss:1.8278
# epoch:360  d_loss:0.5348  g_loss:2.2413
# epoch:361  d_loss:0.4216  g_loss:2.2483
# epoch:362  d_loss:0.4131  g_loss:2.2506
# epoch:363  d_loss:0.4467  g_loss:2.0610
# epoch:364  d_loss:0.4467  g_loss:1.5927
# epoch:365  d_loss:0.3409  g_loss:1.9301
# epoch:366  d_loss:0.3886  g_loss:2.3646
# epoch:367  d_loss:0.4619  g_loss:2.0358
# epoch:368  d_loss:0.2728  g_loss:2.5921
# epoch:369  d_loss:0.3089  g_loss:2.0087
# epoch:370  d_loss:0.4877  g_loss:2.0141
# epoch:371  d_loss:0.2713  g_loss:2.3675
# epoch:372  d_loss:0.3029  g_loss:2.3192
# epoch:373  d_loss:0.4160  g_loss:2.7947
# epoch:374  d_loss:0.3407  g_loss:3.0329
# epoch:375  d_loss:0.3777  g_loss:2.3762
# epoch:376  d_loss:0.5422  g_loss:1.8507
# epoch:377  d_loss:0.3210  g_loss:1.9470
# epoch:378  d_loss:0.3741  g_loss:2.2372
# epoch:379  d_loss:0.3792  g_loss:2.3847
# epoch:380  d_loss:0.4623  g_loss:2.2000
# epoch:381  d_loss:0.4002  g_loss:2.2550
# epoch:382  d_loss:0.5170  g_loss:2.0050
# epoch:383  d_loss:0.4428  g_loss:1.8051
# epoch:384  d_loss:0.4790  g_loss:1.7242
# epoch:385  d_loss:0.4697  g_loss:1.5682
# epoch:386  d_loss:0.4047  g_loss:1.9700
# epoch:387  d_loss:0.3705  g_loss:2.1199
# epoch:388  d_loss:0.5867  g_loss:2.0425
# epoch:389  d_loss:0.4562  g_loss:1.9697
# epoch:390  d_loss:0.4131  g_loss:2.2079
# epoch:391  d_loss:0.2902  g_loss:2.4615
# epoch:392  d_loss:0.3879  g_loss:2.2141
# epoch:393  d_loss:0.2401  g_loss:2.8699
# epoch:394  d_loss:0.3253  g_loss:2.6947
# epoch:395  d_loss:0.3020  g_loss:2.3101
# epoch:396  d_loss:0.3444  g_loss:2.4914
# epoch:397  d_loss:0.2350  g_loss:2.1339
# epoch:398  d_loss:0.4001  g_loss:1.9881
# epoch:399  d_loss:0.3565  g_loss:2.0522
# epoch:400  d_loss:0.1958  g_loss:2.7600
# epoch:401  d_loss:0.2936  g_loss:3.0516
# epoch:402  d_loss:0.3371  g_loss:2.9259
# epoch:403  d_loss:0.2753  g_loss:2.7366
# epoch:404  d_loss:0.3394  g_loss:2.5247
# epoch:405  d_loss:0.2851  g_loss:2.1581
# epoch:406  d_loss:0.2967  g_loss:2.2373
# epoch:407  d_loss:0.2988  g_loss:2.1534
# epoch:408  d_loss:0.2096  g_loss:2.5564
# epoch:409  d_loss:0.4301  g_loss:2.6206
# epoch:410  d_loss:0.2855  g_loss:2.3584
# epoch:411  d_loss:0.3827  g_loss:2.3540
# epoch:412  d_loss:0.4157  g_loss:1.8347
# epoch:413  d_loss:0.4139  g_loss:2.2096
# epoch:414  d_loss:0.3987  g_loss:2.1810
# epoch:415  d_loss:0.4739  g_loss:2.5484
# epoch:416  d_loss:0.3712  g_loss:2.9468
# epoch:417  d_loss:0.5261  g_loss:2.1291
# epoch:418  d_loss:0.4104  g_loss:1.7595
# epoch:419  d_loss:0.4542  g_loss:1.7677
# epoch:420  d_loss:0.4020  g_loss:2.0048
# epoch:421  d_loss:0.3809  g_loss:1.9831
# epoch:422  d_loss:0.4095  g_loss:1.9759
# epoch:423  d_loss:0.4779  g_loss:1.8405
# epoch:424  d_loss:0.5198  g_loss:1.4303
# epoch:425  d_loss:0.3495  g_loss:2.0167
# epoch:426  d_loss:0.3514  g_loss:2.3395
# epoch:427  d_loss:0.3250  g_loss:3.1204
# epoch:428  d_loss:0.3425  g_loss:3.3598
# epoch:429  d_loss:0.5229  g_loss:2.4772
# epoch:430  d_loss:0.3483  g_loss:1.9115
# epoch:431  d_loss:0.3706  g_loss:1.8432
# epoch:432  d_loss:0.3572  g_loss:2.6524
# epoch:433  d_loss:0.3604  g_loss:2.7085
# epoch:434  d_loss:0.3976  g_loss:2.4290
# epoch:435  d_loss:0.3058  g_loss:2.0875
# epoch:436  d_loss:0.3368  g_loss:2.3237
# epoch:437  d_loss:0.2918  g_loss:2.3479
# epoch:438  d_loss:0.3469  g_loss:2.7479
# epoch:439  d_loss:0.2065  g_loss:2.6014
# epoch:440  d_loss:0.2099  g_loss:2.5939
# epoch:441  d_loss:0.2770  g_loss:2.5768
# epoch:442  d_loss:0.2068  g_loss:2.5123
# epoch:443  d_loss:0.3092  g_loss:2.7524
# epoch:444  d_loss:0.2643  g_loss:2.0127
# epoch:445  d_loss:0.3389  g_loss:2.1344
# epoch:446  d_loss:0.2761  g_loss:2.3525
# epoch:447  d_loss:0.2393  g_loss:1.9879
# epoch:448  d_loss:0.2959  g_loss:2.0756
# epoch:449  d_loss:0.3939  g_loss:2.0720
# epoch:450  d_loss:0.2387  g_loss:2.3891
# epoch:451  d_loss:0.2815  g_loss:2.1783
# epoch:452  d_loss:0.3782  g_loss:2.5642
# epoch:453  d_loss:0.2284  g_loss:2.6120
# epoch:454  d_loss:0.3388  g_loss:1.7262
# epoch:455  d_loss:0.2744  g_loss:2.1796
# epoch:456  d_loss:0.3497  g_loss:1.9895
# epoch:457  d_loss:0.2655  g_loss:2.7156
# epoch:458  d_loss:0.2057  g_loss:2.9920
# epoch:459  d_loss:0.2698  g_loss:2.7400
# epoch:460  d_loss:0.2302  g_loss:2.4621
# epoch:461  d_loss:0.2547  g_loss:2.8043
# epoch:462  d_loss:0.3229  g_loss:2.6882
# epoch:463  d_loss:0.1970  g_loss:2.8940
# epoch:464  d_loss:0.1780  g_loss:2.8622
# epoch:465  d_loss:0.3199  g_loss:2.4157
# epoch:466  d_loss:0.2831  g_loss:2.6700
# epoch:467  d_loss:0.3175  g_loss:2.4101
# epoch:468  d_loss:0.2014  g_loss:2.7649
# epoch:469  d_loss:0.3150  g_loss:2.8081
# epoch:470  d_loss:0.4137  g_loss:2.4943
# epoch:471  d_loss:0.3706  g_loss:2.4000
# epoch:472  d_loss:0.3203  g_loss:3.0512
# epoch:473  d_loss:0.4928  g_loss:2.8232
# epoch:474  d_loss:0.2242  g_loss:3.4305
# epoch:475  d_loss:0.5171  g_loss:2.4026
# epoch:476  d_loss:0.3509  g_loss:2.1285
# epoch:477  d_loss:0.2936  g_loss:2.1055
# epoch:478  d_loss:0.2360  g_loss:2.9294
# epoch:479  d_loss:0.3541  g_loss:2.2452
# epoch:480  d_loss:0.2805  g_loss:2.2036
# epoch:481  d_loss:0.2435  g_loss:2.1831
# epoch:482  d_loss:0.4277  g_loss:2.5553
# epoch:483  d_loss:0.2308  g_loss:2.4508
# epoch:484  d_loss:0.2790  g_loss:2.2234
# epoch:485  d_loss:0.2777  g_loss:2.5886
# epoch:486  d_loss:0.3160  g_loss:2.3085
# epoch:487  d_loss:0.3260  g_loss:2.5418
# epoch:488  d_loss:0.3265  g_loss:2.3898
# epoch:489  d_loss:0.2939  g_loss:2.2551
# epoch:490  d_loss:0.3579  g_loss:2.4839
# epoch:491  d_loss:0.2876  g_loss:2.3075
# epoch:492  d_loss:0.2524  g_loss:2.2481
# epoch:493  d_loss:0.2339  g_loss:2.2052
# epoch:494  d_loss:0.3688  g_loss:2.5135
# epoch:495  d_loss:0.2522  g_loss:2.5366
# epoch:496  d_loss:0.2678  g_loss:2.6757
# epoch:497  d_loss:0.2912  g_loss:2.0768
# epoch:498  d_loss:0.2902  g_loss:2.2053
# epoch:499  d_loss:0.3340  g_loss:2.3651
# epoch:500  d_loss:0.3011  g_loss:2.7021
# epoch:501  d_loss:0.3109  g_loss:2.6652
# epoch:502  d_loss:0.5024  g_loss:2.5495
# epoch:503  d_loss:0.3615  g_loss:2.4982
# epoch:504  d_loss:0.3647  g_loss:1.9114
# epoch:505  d_loss:0.4479  g_loss:1.6740
# epoch:506  d_loss:0.4002  g_loss:2.0667
# epoch:507  d_loss:0.3484  g_loss:2.7093
# epoch:508  d_loss:0.4628  g_loss:2.5856
# epoch:509  d_loss:0.2360  g_loss:2.8235
# epoch:510  d_loss:0.3044  g_loss:2.7617
# epoch:511  d_loss:0.3083  g_loss:2.7175
# epoch:512  d_loss:0.4264  g_loss:1.9056
# epoch:513  d_loss:0.3751  g_loss:2.1521
# epoch:514  d_loss:0.2344  g_loss:2.9087
# epoch:515  d_loss:0.2527  g_loss:2.9767
# epoch:516  d_loss:0.2117  g_loss:2.6492
# epoch:517  d_loss:0.2427  g_loss:2.8850
# epoch:518  d_loss:0.2212  g_loss:2.2613
# epoch:519  d_loss:0.2299  g_loss:2.3617
# epoch:520  d_loss:0.1442  g_loss:2.8360
# epoch:521  d_loss:0.1651  g_loss:3.0936
# epoch:522  d_loss:0.1733  g_loss:3.2827
# epoch:523  d_loss:0.1551  g_loss:3.0378
# epoch:524  d_loss:0.2263  g_loss:3.1971
# epoch:525  d_loss:0.1233  g_loss:2.9438
# epoch:526  d_loss:0.1412  g_loss:2.7109
# epoch:527  d_loss:0.2540  g_loss:2.7362
# epoch:528  d_loss:0.2129  g_loss:2.9099
# epoch:529  d_loss:0.2189  g_loss:2.8675
# epoch:530  d_loss:0.1514  g_loss:2.9361
# epoch:531  d_loss:0.1314  g_loss:3.2271
# epoch:532  d_loss:0.1587  g_loss:3.4953
# epoch:533  d_loss:0.2497  g_loss:2.7226
# epoch:534  d_loss:0.2074  g_loss:2.4416
# epoch:535  d_loss:0.1062  g_loss:3.6018
# epoch:536  d_loss:0.1844  g_loss:2.9047
# epoch:537  d_loss:0.2444  g_loss:2.0976
# epoch:538  d_loss:0.1924  g_loss:2.8834
# epoch:539  d_loss:0.2378  g_loss:3.0991
# epoch:540  d_loss:0.2041  g_loss:2.6498
# epoch:541  d_loss:0.1847  g_loss:3.0661
# epoch:542  d_loss:0.3341  g_loss:2.2966
# epoch:543  d_loss:0.3795  g_loss:2.0614
# epoch:544  d_loss:0.3343  g_loss:2.0664
# epoch:545  d_loss:0.4898  g_loss:1.9427
# epoch:546  d_loss:0.2124  g_loss:3.7048
# epoch:547  d_loss:0.4126  g_loss:2.2976
# epoch:548  d_loss:0.6044  g_loss:1.7954
# epoch:549  d_loss:0.2946  g_loss:2.6208
# epoch:550  d_loss:0.4075  g_loss:3.1119
# epoch:551  d_loss:0.3970  g_loss:2.8166
# epoch:552  d_loss:0.7877  g_loss:2.3436
# epoch:553  d_loss:0.8298  g_loss:1.4118
# epoch:554  d_loss:0.6493  g_loss:1.7023
# epoch:555  d_loss:0.4034  g_loss:2.3591
# epoch:556  d_loss:0.3874  g_loss:2.6424
# epoch:557  d_loss:0.3825  g_loss:2.2530
# epoch:558  d_loss:0.2266  g_loss:2.0595
# epoch:559  d_loss:0.3274  g_loss:1.6141
# epoch:560  d_loss:0.2630  g_loss:2.2952
# epoch:561  d_loss:0.3943  g_loss:2.2872
# epoch:562  d_loss:0.2191  g_loss:2.3650
# epoch:563  d_loss:0.3289  g_loss:2.1658
# epoch:564  d_loss:0.2982  g_loss:2.6932
# epoch:565  d_loss:0.2728  g_loss:2.5363
# epoch:566  d_loss:0.2822  g_loss:2.8951
# epoch:567  d_loss:0.1848  g_loss:3.3089
# epoch:568  d_loss:0.2215  g_loss:2.6612
# epoch:569  d_loss:0.1562  g_loss:2.6797
# epoch:570  d_loss:0.1801  g_loss:2.8579
# epoch:571  d_loss:0.1931  g_loss:2.6874
# epoch:572  d_loss:0.1349  g_loss:2.8962
# epoch:573  d_loss:0.2356  g_loss:3.0285
# epoch:574  d_loss:0.1780  g_loss:2.9577
# epoch:575  d_loss:0.1564  g_loss:2.7857
# epoch:576  d_loss:0.2135  g_loss:2.6572
# epoch:577  d_loss:0.1795  g_loss:2.9090
# epoch:578  d_loss:0.2393  g_loss:2.4954
# epoch:579  d_loss:0.2089  g_loss:2.2659
# epoch:580  d_loss:0.2788  g_loss:2.2825
# epoch:581  d_loss:0.1953  g_loss:2.2932
# epoch:582  d_loss:0.1971  g_loss:2.8023
# epoch:583  d_loss:0.4077  g_loss:2.0179
# epoch:584  d_loss:0.2763  g_loss:1.6254
# epoch:585  d_loss:0.4938  g_loss:1.5956
# epoch:586  d_loss:0.2127  g_loss:3.2523
# epoch:587  d_loss:0.5069  g_loss:3.0991
# epoch:588  d_loss:0.2938  g_loss:2.4080
# epoch:589  d_loss:0.5972  g_loss:1.4484
# epoch:590  d_loss:0.4498  g_loss:1.5325
# epoch:591  d_loss:0.3974  g_loss:2.5019
# epoch:592  d_loss:0.5515  g_loss:3.1052
# epoch:593  d_loss:0.5026  g_loss:2.3727
# epoch:594  d_loss:0.6817  g_loss:1.5955
# epoch:595  d_loss:0.5698  g_loss:1.3033
# epoch:596  d_loss:0.4506  g_loss:1.2999
# epoch:597  d_loss:0.4860  g_loss:1.6901
# epoch:598  d_loss:0.3201  g_loss:2.1664
# epoch:599  d_loss:0.3823  g_loss:2.2019
# epoch:600  d_loss:0.4252  g_loss:2.0761
# epoch:601  d_loss:0.4706  g_loss:1.1524
# epoch:602  d_loss:0.5723  g_loss:1.4273
# epoch:603  d_loss:0.3842  g_loss:1.9712
# epoch:604  d_loss:0.3747  g_loss:1.8383
# epoch:605  d_loss:0.6018  g_loss:1.5016
# epoch:606  d_loss:0.4642  g_loss:1.5166
# epoch:607  d_loss:0.4373  g_loss:1.3455
# epoch:608  d_loss:0.4681  g_loss:1.7327
# epoch:609  d_loss:0.4287  g_loss:2.9110
# epoch:610  d_loss:0.2708  g_loss:2.9007
# epoch:611  d_loss:0.3373  g_loss:2.4249
# epoch:612  d_loss:0.5315  g_loss:1.5955
# epoch:613  d_loss:0.8984  g_loss:1.8191
# epoch:614  d_loss:1.1900  g_loss:1.3283
# epoch:615  d_loss:0.9430  g_loss:2.0688
# epoch:616  d_loss:0.4376  g_loss:3.5174
# epoch:617  d_loss:0.8031  g_loss:3.6323
# epoch:618  d_loss:0.7345  g_loss:2.9927
# epoch:619  d_loss:0.7787  g_loss:2.4889
# epoch:620  d_loss:0.7621  g_loss:1.2560
# epoch:621  d_loss:0.5095  g_loss:1.2415
# epoch:622  d_loss:0.8562  g_loss:0.9358
# epoch:623  d_loss:0.6231  g_loss:1.1426
# epoch:624  d_loss:0.8004  g_loss:1.2684
# epoch:625  d_loss:0.6158  g_loss:1.2733
# epoch:626  d_loss:0.6826  g_loss:1.6577
# epoch:627  d_loss:0.5218  g_loss:2.0400
# epoch:628  d_loss:0.3622  g_loss:2.3948
# epoch:629  d_loss:0.2602  g_loss:1.9601
# epoch:630  d_loss:0.3843  g_loss:1.6051
# epoch:631  d_loss:0.4240  g_loss:1.4659
# epoch:632  d_loss:0.3026  g_loss:1.7460
# epoch:633  d_loss:0.2734  g_loss:2.2467
# epoch:634  d_loss:0.3860  g_loss:1.9932
# epoch:635  d_loss:0.4069  g_loss:2.2714
# epoch:636  d_loss:0.4812  g_loss:2.5525
# epoch:637  d_loss:0.6725  g_loss:2.7009
# epoch:638  d_loss:1.0760  g_loss:2.0493
# epoch:639  d_loss:1.1214  g_loss:2.0306
# epoch:640  d_loss:1.3834  g_loss:1.9652
# epoch:641  d_loss:1.1735  g_loss:1.6052
# epoch:642  d_loss:0.6563  g_loss:2.1035
# epoch:643  d_loss:0.4575  g_loss:3.4672
# epoch:644  d_loss:0.5642  g_loss:3.4013
# epoch:645  d_loss:0.9341  g_loss:4.7096
# epoch:646  d_loss:1.1203  g_loss:3.3359
# epoch:647  d_loss:0.6575  g_loss:3.1782
# epoch:648  d_loss:0.4846  g_loss:2.2079
# epoch:649  d_loss:0.5896  g_loss:1.7843
# epoch:650  d_loss:0.4058  g_loss:1.8744
# epoch:651  d_loss:0.7844  g_loss:1.4246
# epoch:652  d_loss:0.5115  g_loss:1.3478
# epoch:653  d_loss:0.5270  g_loss:1.5232
# epoch:654  d_loss:0.6825  g_loss:1.5350
# epoch:655  d_loss:0.6336  g_loss:1.1958
# epoch:656  d_loss:0.5988  g_loss:1.5500
# epoch:657  d_loss:0.7899  g_loss:1.3431
# epoch:658  d_loss:0.8027  g_loss:0.9687
# epoch:659  d_loss:0.8414  g_loss:0.9866
# epoch:660  d_loss:0.5906  g_loss:1.1380
# epoch:661  d_loss:0.5262  g_loss:1.3631
# epoch:662  d_loss:0.4085  g_loss:1.4502
# epoch:663  d_loss:0.5123  g_loss:1.4814
# epoch:664  d_loss:0.3012  g_loss:1.7896
# epoch:665  d_loss:0.3875  g_loss:2.0797
# epoch:666  d_loss:0.2918  g_loss:2.3649
# epoch:667  d_loss:0.2417  g_loss:2.2707
# epoch:668  d_loss:0.2843  g_loss:2.0812
# epoch:669  d_loss:0.1819  g_loss:2.4404
# epoch:670  d_loss:0.2415  g_loss:2.7517
# epoch:671  d_loss:0.2126  g_loss:3.1752
# epoch:672  d_loss:0.4529  g_loss:2.7266
# epoch:673  d_loss:0.5617  g_loss:2.3800
# epoch:674  d_loss:0.4489  g_loss:2.8640
# epoch:675  d_loss:0.5307  g_loss:2.5404
# epoch:676  d_loss:0.8077  g_loss:2.3917
# epoch:677  d_loss:1.3017  g_loss:1.2528
# epoch:678  d_loss:1.1219  g_loss:0.9561
# epoch:679  d_loss:0.8261  g_loss:1.2783
# epoch:680  d_loss:0.9120  g_loss:1.2299
# epoch:681  d_loss:0.5725  g_loss:1.6645
# epoch:682  d_loss:0.3874  g_loss:2.5952
# epoch:683  d_loss:0.3016  g_loss:2.9928
# epoch:684  d_loss:0.2921  g_loss:3.4344
# epoch:685  d_loss:0.3439  g_loss:3.1141
# epoch:686  d_loss:0.3505  g_loss:3.0000
# epoch:687  d_loss:0.2273  g_loss:3.1124
# epoch:688  d_loss:0.2864  g_loss:3.0978
# epoch:689  d_loss:0.1449  g_loss:2.7610
# epoch:690  d_loss:0.4614  g_loss:2.5590
# epoch:691  d_loss:0.4311  g_loss:2.7227
# epoch:692  d_loss:0.2716  g_loss:2.2510
# epoch:693  d_loss:0.3302  g_loss:1.9823
# epoch:694  d_loss:0.4058  g_loss:1.8258
# epoch:695  d_loss:0.5964  g_loss:1.4556
# epoch:696  d_loss:0.3606  g_loss:1.3439
# epoch:697  d_loss:0.5382  g_loss:1.3398
# epoch:698  d_loss:0.5551  g_loss:1.1581
# epoch:699  d_loss:0.5449  g_loss:1.4877
# epoch:700  d_loss:0.4738  g_loss:1.3889
# epoch:701  d_loss:0.5690  g_loss:1.2762
# epoch:702  d_loss:0.6160  g_loss:1.4638
# epoch:703  d_loss:0.7762  g_loss:1.2066
# epoch:704  d_loss:0.5439  g_loss:1.2680
# epoch:705  d_loss:0.5871  g_loss:1.2530
# epoch:706  d_loss:0.5886  g_loss:1.3198
# epoch:707  d_loss:0.3692  g_loss:1.5822
# epoch:708  d_loss:0.6210  g_loss:1.6490
# epoch:709  d_loss:0.4045  g_loss:1.7238
# epoch:710  d_loss:0.4072  g_loss:1.8207
# epoch:711  d_loss:0.3652  g_loss:1.7234
# epoch:712  d_loss:0.4133  g_loss:1.5442
# epoch:713  d_loss:0.3472  g_loss:1.4914
# epoch:714  d_loss:0.3099  g_loss:1.4548
# epoch:715  d_loss:0.3642  g_loss:1.6322
# epoch:716  d_loss:0.3742  g_loss:1.8619
# epoch:717  d_loss:0.2136  g_loss:2.2984
# epoch:718  d_loss:0.5025  g_loss:2.1249
# epoch:719  d_loss:0.4401  g_loss:2.0737
# epoch:720  d_loss:0.5535  g_loss:1.7765
# epoch:721  d_loss:0.6669  g_loss:1.3563
# epoch:722  d_loss:0.3602  g_loss:1.5836
# epoch:723  d_loss:0.4497  g_loss:1.1705
# epoch:724  d_loss:0.4923  g_loss:1.2813
# epoch:725  d_loss:0.4473  g_loss:1.4980
# epoch:726  d_loss:0.5498  g_loss:1.3081
# epoch:727  d_loss:0.5683  g_loss:1.4959
# epoch:728  d_loss:0.5878  g_loss:1.3889
# epoch:729  d_loss:0.5596  g_loss:1.5513
# epoch:730  d_loss:0.6836  g_loss:1.5674
# epoch:731  d_loss:0.5656  g_loss:1.5969
# epoch:732  d_loss:0.5304  g_loss:1.4130
# epoch:733  d_loss:0.6490  g_loss:1.2752
# epoch:734  d_loss:0.6024  g_loss:1.0757
# epoch:735  d_loss:0.5864  g_loss:1.0838
# epoch:736  d_loss:0.4979  g_loss:1.2930
# epoch:737  d_loss:0.5029  g_loss:1.3263
# epoch:738  d_loss:0.5114  g_loss:1.3820
# epoch:739  d_loss:0.4924  g_loss:1.5979
# epoch:740  d_loss:0.4916  g_loss:1.4971
# epoch:741  d_loss:0.6197  g_loss:1.2548
# epoch:742  d_loss:0.5474  g_loss:1.2866
# epoch:743  d_loss:0.4698  g_loss:1.2267
# epoch:744  d_loss:0.4882  g_loss:1.4375
# epoch:745  d_loss:0.4031  g_loss:1.3616
# epoch:746  d_loss:0.7043  g_loss:1.1630
# epoch:747  d_loss:0.3694  g_loss:1.4823
# epoch:748  d_loss:0.5247  g_loss:1.0703
# epoch:749  d_loss:0.6514  g_loss:1.2976
# epoch:750  d_loss:0.6922  g_loss:1.1605
# epoch:751  d_loss:0.7071  g_loss:0.9143
# epoch:752  d_loss:0.6687  g_loss:0.8850
# epoch:753  d_loss:0.5821  g_loss:1.0018
# epoch:754  d_loss:0.6047  g_loss:0.9132
# epoch:755  d_loss:0.6394  g_loss:0.9761
# epoch:756  d_loss:0.5627  g_loss:1.0184
# epoch:757  d_loss:0.4630  g_loss:1.0786
# epoch:758  d_loss:0.5729  g_loss:1.1882
# epoch:759  d_loss:0.4662  g_loss:1.1935
# epoch:760  d_loss:0.5472  g_loss:1.1733
# epoch:761  d_loss:0.5341  g_loss:1.0788
# epoch:762  d_loss:0.4928  g_loss:1.2812
# epoch:763  d_loss:0.4134  g_loss:1.1926
# epoch:764  d_loss:0.4658  g_loss:1.4006
# epoch:765  d_loss:0.4100  g_loss:1.3027
# epoch:766  d_loss:0.3414  g_loss:1.5267
# epoch:767  d_loss:0.4017  g_loss:1.4305
# epoch:768  d_loss:0.3665  g_loss:1.7571
# epoch:769  d_loss:0.3549  g_loss:1.5930
# epoch:770  d_loss:0.2854  g_loss:1.7691
# epoch:771  d_loss:0.2624  g_loss:1.9009
# epoch:772  d_loss:0.2888  g_loss:1.7925
# epoch:773  d_loss:0.2822  g_loss:1.8634
# epoch:774  d_loss:0.3799  g_loss:1.6809
# epoch:775  d_loss:0.2809  g_loss:1.8956
# epoch:776  d_loss:0.3515  g_loss:1.8375
# epoch:777  d_loss:0.3651  g_loss:1.7653
# epoch:778  d_loss:0.4041  g_loss:2.1775
# epoch:779  d_loss:0.4528  g_loss:1.4798
# epoch:780  d_loss:0.4663  g_loss:1.5719
# epoch:781  d_loss:0.4757  g_loss:1.4241
# epoch:782  d_loss:0.4194  g_loss:1.8392
# epoch:783  d_loss:0.3724  g_loss:2.0495
# epoch:784  d_loss:0.5333  g_loss:1.6340
# epoch:785  d_loss:0.3628  g_loss:1.5990
# epoch:786  d_loss:0.5155  g_loss:1.5033
# epoch:787  d_loss:0.4542  g_loss:1.5732
# epoch:788  d_loss:0.5678  g_loss:1.5381
# epoch:789  d_loss:0.4947  g_loss:1.5833
# epoch:790  d_loss:0.6468  g_loss:1.4500
# epoch:791  d_loss:0.6987  g_loss:1.1847
# epoch:792  d_loss:0.4938  g_loss:1.1012
# epoch:793  d_loss:0.7629  g_loss:1.2448
# epoch:794  d_loss:0.5747  g_loss:1.3218
# epoch:795  d_loss:0.5469  g_loss:1.2913
# epoch:796  d_loss:0.5091  g_loss:1.2219
# epoch:797  d_loss:0.5864  g_loss:1.0961
# epoch:798  d_loss:0.5520  g_loss:1.4662
# epoch:799  d_loss:0.5275  g_loss:1.3048
# epoch:800  d_loss:0.5474  g_loss:1.4723
# epoch:801  d_loss:0.4697  g_loss:1.5006
# epoch:802  d_loss:0.4315  g_loss:1.5189
# epoch:803  d_loss:0.4453  g_loss:1.2675
# epoch:804  d_loss:0.4436  g_loss:1.3748
# epoch:805  d_loss:0.5602  g_loss:1.3375
# epoch:806  d_loss:0.3797  g_loss:1.5228
# epoch:807  d_loss:0.3954  g_loss:1.7928
# epoch:808  d_loss:0.5096  g_loss:1.7117
# epoch:809  d_loss:0.5043  g_loss:1.7685
# epoch:810  d_loss:0.4319  g_loss:1.8627
# epoch:811  d_loss:0.3595  g_loss:1.5751
# epoch:812  d_loss:0.3971  g_loss:1.7138
# epoch:813  d_loss:0.4426  g_loss:1.2824
# epoch:814  d_loss:0.2865  g_loss:1.4140
# epoch:815  d_loss:0.6511  g_loss:1.1255
# epoch:816  d_loss:0.4986  g_loss:1.5061
# epoch:817  d_loss:0.4229  g_loss:2.0103
# epoch:818  d_loss:0.3622  g_loss:1.9417
# epoch:819  d_loss:0.4283  g_loss:2.0144
# epoch:820  d_loss:0.6665  g_loss:1.6832
# epoch:821  d_loss:0.7525  g_loss:1.1647
# epoch:822  d_loss:0.5217  g_loss:1.5240
# epoch:823  d_loss:0.7001  g_loss:1.5896
# epoch:824  d_loss:0.5321  g_loss:1.6300
# epoch:825  d_loss:0.5699  g_loss:1.7717
# epoch:826  d_loss:0.4373  g_loss:1.8551
# epoch:827  d_loss:0.5855  g_loss:1.4746
# epoch:828  d_loss:0.4836  g_loss:1.4230
# epoch:829  d_loss:0.4728  g_loss:1.1641
# epoch:830  d_loss:0.4711  g_loss:1.3396
# epoch:831  d_loss:0.4678  g_loss:1.7422
# epoch:832  d_loss:0.4277  g_loss:2.1712
# epoch:833  d_loss:0.3605  g_loss:2.0523
# epoch:834  d_loss:0.3918  g_loss:1.9633
# epoch:835  d_loss:0.4339  g_loss:1.4367
# epoch:836  d_loss:0.4312  g_loss:1.8467
# epoch:837  d_loss:0.3989  g_loss:1.7351
# epoch:838  d_loss:0.1940  g_loss:2.3312
# epoch:839  d_loss:0.2666  g_loss:2.8459
# epoch:840  d_loss:0.2243  g_loss:2.4861
# epoch:841  d_loss:0.3279  g_loss:2.2247
# epoch:842  d_loss:0.2813  g_loss:1.9449
# epoch:843  d_loss:0.4079  g_loss:2.1446
# epoch:844  d_loss:0.3340  g_loss:2.1408
# epoch:845  d_loss:0.2062  g_loss:2.6384
# epoch:846  d_loss:0.2483  g_loss:2.6094
# epoch:847  d_loss:0.3721  g_loss:2.1822
# epoch:848  d_loss:0.2951  g_loss:1.8904
# epoch:849  d_loss:0.3490  g_loss:2.0998
# epoch:850  d_loss:0.3241  g_loss:1.9290
# epoch:851  d_loss:0.4209  g_loss:1.9315
# epoch:852  d_loss:0.4546  g_loss:1.7103
# epoch:853  d_loss:0.4819  g_loss:1.9128
# epoch:854  d_loss:0.4145  g_loss:1.9124
# epoch:855  d_loss:0.6598  g_loss:1.6760
# epoch:856  d_loss:0.5292  g_loss:1.9127
# epoch:857  d_loss:0.5260  g_loss:1.7361
# epoch:858  d_loss:0.4135  g_loss:1.4836
# epoch:859  d_loss:0.4426  g_loss:1.5539
# epoch:860  d_loss:0.4342  g_loss:1.8418
# epoch:861  d_loss:0.5824  g_loss:1.4520
# epoch:862  d_loss:0.6011  g_loss:1.5093
# epoch:863  d_loss:0.5206  g_loss:1.7695
# epoch:864  d_loss:0.6347  g_loss:1.4651
# epoch:865  d_loss:0.3949  g_loss:1.6458
# epoch:866  d_loss:0.4992  g_loss:1.4713
# epoch:867  d_loss:0.3941  g_loss:1.5316
# epoch:868  d_loss:0.4691  g_loss:1.5563
# epoch:869  d_loss:0.3389  g_loss:1.8338
# epoch:870  d_loss:0.4281  g_loss:2.2161
# epoch:871  d_loss:0.4131  g_loss:1.8888
# epoch:872  d_loss:0.3181  g_loss:1.9037
# epoch:873  d_loss:0.4255  g_loss:1.6156
# epoch:874  d_loss:0.3471  g_loss:1.6208
# epoch:875  d_loss:0.4413  g_loss:1.8562
# epoch:876  d_loss:0.3379  g_loss:2.0613
# epoch:877  d_loss:0.4034  g_loss:2.3088
# epoch:878  d_loss:0.4656  g_loss:1.5937
# epoch:879  d_loss:0.5043  g_loss:1.5404
# epoch:880  d_loss:0.4722  g_loss:1.5447
# epoch:881  d_loss:0.3331  g_loss:1.6444
# epoch:882  d_loss:0.5363  g_loss:1.5063
# epoch:883  d_loss:0.5422  g_loss:1.8107
# epoch:884  d_loss:0.5212  g_loss:1.6888
# epoch:885  d_loss:0.3943  g_loss:1.9847
# epoch:886  d_loss:0.4705  g_loss:1.8285
# epoch:887  d_loss:0.4620  g_loss:1.9221
# epoch:888  d_loss:0.4462  g_loss:1.7035
# epoch:889  d_loss:0.4817  g_loss:1.7657
# epoch:890  d_loss:0.4362  g_loss:1.9820
# epoch:891  d_loss:0.3824  g_loss:2.0402
# epoch:892  d_loss:0.4261  g_loss:1.8500
# epoch:893  d_loss:0.3308  g_loss:1.8623
# epoch:894  d_loss:0.4850  g_loss:1.6233
# epoch:895  d_loss:0.3393  g_loss:2.0697
# epoch:896  d_loss:0.2874  g_loss:1.9899
# epoch:897  d_loss:0.3216  g_loss:1.9727
# epoch:898  d_loss:0.4300  g_loss:1.8896
# epoch:899  d_loss:0.3100  g_loss:2.2097
# epoch:900  d_loss:0.3864  g_loss:2.0668
# epoch:901  d_loss:0.4140  g_loss:1.8804
# epoch:902  d_loss:0.3362  g_loss:1.6830
# epoch:903  d_loss:0.5707  g_loss:1.8472
# epoch:904  d_loss:0.3091  g_loss:2.1518
# epoch:905  d_loss:0.3461  g_loss:1.7593
# epoch:906  d_loss:0.4197  g_loss:2.0488
# epoch:907  d_loss:0.4438  g_loss:2.0836
# epoch:908  d_loss:0.4123  g_loss:2.0185
# epoch:909  d_loss:0.4705  g_loss:2.1794
# epoch:910  d_loss:0.5272  g_loss:1.7961
# epoch:911  d_loss:0.4569  g_loss:1.9077
# epoch:912  d_loss:0.3157  g_loss:2.1680
# epoch:913  d_loss:0.4254  g_loss:2.0326
# epoch:914  d_loss:0.4329  g_loss:2.0051
# epoch:915  d_loss:0.4197  g_loss:1.6816
# epoch:916  d_loss:0.4385  g_loss:1.9728
# epoch:917  d_loss:0.3317  g_loss:1.8170
# epoch:918  d_loss:0.3786  g_loss:1.9948
# epoch:919  d_loss:0.4278  g_loss:1.9472
# epoch:920  d_loss:0.4126  g_loss:2.1342
# epoch:921  d_loss:0.5627  g_loss:1.8521
# epoch:922  d_loss:0.5093  g_loss:2.0864
# epoch:923  d_loss:0.6327  g_loss:2.0397
# epoch:924  d_loss:0.5372  g_loss:1.5259
# epoch:925  d_loss:0.4505  g_loss:1.6962
# epoch:926  d_loss:0.3215  g_loss:1.7233
# epoch:927  d_loss:0.5048  g_loss:2.0156
# epoch:928  d_loss:0.4606  g_loss:1.9437
# epoch:929  d_loss:0.4768  g_loss:1.8191
# epoch:930  d_loss:0.3514  g_loss:2.2656
# epoch:931  d_loss:0.4476  g_loss:1.8238
# epoch:932  d_loss:0.2532  g_loss:2.1096
# epoch:933  d_loss:0.4037  g_loss:1.9854
# epoch:934  d_loss:0.5028  g_loss:1.9188
# epoch:935  d_loss:0.3853  g_loss:1.7124
# epoch:936  d_loss:0.4364  g_loss:1.3235
# epoch:937  d_loss:0.4072  g_loss:2.0217
# epoch:938  d_loss:0.4054  g_loss:2.1019
# epoch:939  d_loss:0.3722  g_loss:2.3727
# epoch:940  d_loss:0.3509  g_loss:2.3068
# epoch:941  d_loss:0.2822  g_loss:2.5737
# epoch:942  d_loss:0.3214  g_loss:2.4276
# epoch:943  d_loss:0.4546  g_loss:2.2909
# epoch:944  d_loss:0.4074  g_loss:1.9654
# epoch:945  d_loss:0.4195  g_loss:2.0347
# epoch:946  d_loss:0.4256  g_loss:2.8265
# epoch:947  d_loss:0.4546  g_loss:2.4763
# epoch:948  d_loss:0.3877  g_loss:2.6950
# epoch:949  d_loss:0.3407  g_loss:2.2545
# epoch:950  d_loss:0.3487  g_loss:1.9490
# epoch:951  d_loss:0.5227  g_loss:2.2070
# epoch:952  d_loss:0.5400  g_loss:2.0481
# epoch:953  d_loss:0.3697  g_loss:2.1930
# epoch:954  d_loss:0.3007  g_loss:2.7563
# epoch:955  d_loss:0.4861  g_loss:2.3843
# epoch:956  d_loss:0.3773  g_loss:2.1980
# epoch:957  d_loss:0.4931  g_loss:1.7835
# epoch:958  d_loss:0.2049  g_loss:3.1071
# epoch:959  d_loss:0.3390  g_loss:2.7065
# epoch:960  d_loss:0.3170  g_loss:2.8389
# epoch:961  d_loss:0.3305  g_loss:2.4835
# epoch:962  d_loss:0.3013  g_loss:2.4537
# epoch:963  d_loss:0.3239  g_loss:2.1361
# epoch:964  d_loss:0.1526  g_loss:2.6113
# epoch:965  d_loss:0.2189  g_loss:2.5980
# epoch:966  d_loss:0.2001  g_loss:2.3583
# epoch:967  d_loss:0.2564  g_loss:2.7143
# epoch:968  d_loss:0.2958  g_loss:2.7717
# epoch:969  d_loss:0.3758  g_loss:2.1703
# epoch:970  d_loss:0.3570  g_loss:2.0230
# epoch:971  d_loss:0.3895  g_loss:1.8280
# epoch:972  d_loss:0.4396  g_loss:1.9095
# epoch:973  d_loss:0.3950  g_loss:2.5889
# epoch:974  d_loss:0.4608  g_loss:2.4105
# epoch:975  d_loss:0.5325  g_loss:2.0185
# epoch:976  d_loss:0.5965  g_loss:1.7523
# epoch:977  d_loss:0.5462  g_loss:1.3893
# epoch:978  d_loss:0.6085  g_loss:1.4343
# epoch:979  d_loss:0.6507  g_loss:1.6636
# epoch:980  d_loss:0.5477  g_loss:1.6442
# epoch:981  d_loss:0.6097  g_loss:1.8040
# epoch:982  d_loss:0.8654  g_loss:1.2977
# epoch:983  d_loss:0.8302  g_loss:1.0432
# epoch:984  d_loss:0.7085  g_loss:1.1966
# epoch:985  d_loss:0.5822  g_loss:1.5609
# epoch:986  d_loss:0.4997  g_loss:1.7647
# epoch:987  d_loss:0.6329  g_loss:1.8851
# epoch:988  d_loss:0.5557  g_loss:1.4981
# epoch:989  d_loss:0.5383  g_loss:1.5282
# epoch:990  d_loss:0.6179  g_loss:1.5221
# epoch:991  d_loss:0.5556  g_loss:1.7308
# epoch:992  d_loss:0.4339  g_loss:2.0008
# epoch:993  d_loss:0.4618  g_loss:2.1506
# epoch:994  d_loss:0.4194  g_loss:2.2068
# epoch:995  d_loss:0.4827  g_loss:1.6509
# epoch:996  d_loss:0.4322  g_loss:1.7425
# epoch:997  d_loss:0.4694  g_loss:1.4129
# epoch:998  d_loss:0.4302  g_loss:1.8642
# epoch:999  d_loss:0.4552  g_loss:1.7095
# epoch:1000  d_loss:0.2814  g_loss:2.5528
# epoch:1001  d_loss:0.3272  g_loss:2.1634
# epoch:1002  d_loss:0.2874  g_loss:2.4631
# epoch:1003  d_loss:0.4830  g_loss:2.7004
# epoch:1004  d_loss:0.2474  g_loss:2.3643
# epoch:1005  d_loss:0.2920  g_loss:2.2476
# epoch:1006  d_loss:0.3243  g_loss:2.1772
# epoch:1007  d_loss:0.3087  g_loss:2.2937
# epoch:1008  d_loss:0.2671  g_loss:2.6056
# epoch:1009  d_loss:0.2266  g_loss:2.7370
# epoch:1010  d_loss:0.2962  g_loss:2.2410
# epoch:1011  d_loss:0.4948  g_loss:1.8033
# epoch:1012  d_loss:0.3142  g_loss:2.1941
# epoch:1013  d_loss:0.2102  g_loss:2.4316
# epoch:1014  d_loss:0.1837  g_loss:3.1537
# epoch:1015  d_loss:0.2924  g_loss:2.2940
# epoch:1016  d_loss:0.4004  g_loss:2.3916
# epoch:1017  d_loss:0.2705  g_loss:2.3617
# epoch:1018  d_loss:0.3943  g_loss:2.4322
# epoch:1019  d_loss:0.3139  g_loss:2.0891
# epoch:1020  d_loss:0.2492  g_loss:2.5429
# epoch:1021  d_loss:0.2353  g_loss:2.6164
# epoch:1022  d_loss:0.5050  g_loss:2.2631
# epoch:1023  d_loss:0.4501  g_loss:1.9179
# epoch:1024  d_loss:0.5178  g_loss:1.8362
# epoch:1025  d_loss:0.5258  g_loss:2.1470
# epoch:1026  d_loss:0.5985  g_loss:1.9094
# epoch:1027  d_loss:0.3144  g_loss:2.2916
# epoch:1028  d_loss:0.5138  g_loss:2.5313
# epoch:1029  d_loss:0.4386  g_loss:2.2251
# epoch:1030  d_loss:0.3217  g_loss:1.8217
# epoch:1031  d_loss:0.4791  g_loss:1.7753
# epoch:1032  d_loss:0.4332  g_loss:1.8236
# epoch:1033  d_loss:0.4121  g_loss:1.9000
# epoch:1034  d_loss:0.4044  g_loss:1.9608
# epoch:1035  d_loss:0.4780  g_loss:2.3139
# epoch:1036  d_loss:0.5374  g_loss:1.9152
# epoch:1037  d_loss:0.5532  g_loss:1.5828
# epoch:1038  d_loss:0.4263  g_loss:1.5407
# epoch:1039  d_loss:0.5314  g_loss:1.6955
# epoch:1040  d_loss:0.5504  g_loss:1.9362
# epoch:1041  d_loss:0.3984  g_loss:2.7061
# epoch:1042  d_loss:0.5340  g_loss:2.3590
# epoch:1043  d_loss:0.4412  g_loss:1.7358
# epoch:1044  d_loss:0.4341  g_loss:2.0710
# epoch:1045  d_loss:0.5530  g_loss:1.7659
# epoch:1046  d_loss:0.3181  g_loss:2.3159
# epoch:1047  d_loss:0.4338  g_loss:2.0825
# epoch:1048  d_loss:0.3946  g_loss:2.0588
# epoch:1049  d_loss:0.3274  g_loss:1.9897
# epoch:1050  d_loss:0.3745  g_loss:1.9083
# epoch:1051  d_loss:0.4463  g_loss:2.0518
# epoch:1052  d_loss:0.3461  g_loss:1.8248
# epoch:1053  d_loss:0.3493  g_loss:2.0412
# epoch:1054  d_loss:0.3879  g_loss:2.1511
# epoch:1055  d_loss:0.3788  g_loss:2.1337
# epoch:1056  d_loss:0.3055  g_loss:2.0487
# epoch:1057  d_loss:0.3695  g_loss:1.9796
# epoch:1058  d_loss:0.3073  g_loss:2.2372
# epoch:1059  d_loss:0.2803  g_loss:2.4416
# epoch:1060  d_loss:0.3570  g_loss:2.0921
# epoch:1061  d_loss:0.2989  g_loss:1.9193
# epoch:1062  d_loss:0.2951  g_loss:2.0766
# epoch:1063  d_loss:0.4356  g_loss:1.8177
# epoch:1064  d_loss:0.3720  g_loss:1.9739
# epoch:1065  d_loss:0.6367  g_loss:1.6829
# epoch:1066  d_loss:0.5300  g_loss:1.8307
# epoch:1067  d_loss:0.5864  g_loss:1.8024
# epoch:1068  d_loss:0.6104  g_loss:1.6948
# epoch:1069  d_loss:0.5499  g_loss:2.0143
# epoch:1070  d_loss:0.4885  g_loss:1.4421
# epoch:1071  d_loss:0.3569  g_loss:1.6081
# epoch:1072  d_loss:0.5209  g_loss:2.0081
# epoch:1073  d_loss:0.4657  g_loss:1.9273
# epoch:1074  d_loss:0.5474  g_loss:1.7026
# epoch:1075  d_loss:0.6292  g_loss:1.3252
# epoch:1076  d_loss:0.5348  g_loss:1.6236
# epoch:1077  d_loss:0.3572  g_loss:1.3943
# epoch:1078  d_loss:0.4767  g_loss:1.4577
# epoch:1079  d_loss:0.4695  g_loss:2.0025
# epoch:1080  d_loss:0.5577  g_loss:1.4783
# epoch:1081  d_loss:0.4430  g_loss:1.7563
# epoch:1082  d_loss:0.4601  g_loss:2.0752
# epoch:1083  d_loss:0.4800  g_loss:1.7614
# epoch:1084  d_loss:0.4395  g_loss:1.6241
# epoch:1085  d_loss:0.3770  g_loss:1.9459
# epoch:1086  d_loss:0.4117  g_loss:1.7187
# epoch:1087  d_loss:0.3105  g_loss:2.3239
# epoch:1088  d_loss:0.4135  g_loss:1.9829
# epoch:1089  d_loss:0.1899  g_loss:2.4110
# epoch:1090  d_loss:0.2270  g_loss:2.6751
# epoch:1091  d_loss:0.2459  g_loss:2.2307
# epoch:1092  d_loss:0.1943  g_loss:2.9348
# epoch:1093  d_loss:0.2187  g_loss:2.2023
# epoch:1094  d_loss:0.3209  g_loss:2.7600
# epoch:1095  d_loss:0.2700  g_loss:2.2502
# epoch:1096  d_loss:0.2841  g_loss:2.3912
# epoch:1097  d_loss:0.2105  g_loss:2.7983
# epoch:1098  d_loss:0.3012  g_loss:2.9032
# epoch:1099  d_loss:0.3397  g_loss:2.4677
# epoch:1100  d_loss:0.3695  g_loss:2.3312
# epoch:1101  d_loss:0.4266  g_loss:2.3055
# epoch:1102  d_loss:0.2837  g_loss:2.4434
# epoch:1103  d_loss:0.3609  g_loss:2.1524
# epoch:1104  d_loss:0.3411  g_loss:2.0107
# epoch:1105  d_loss:0.2743  g_loss:2.3838
# epoch:1106  d_loss:0.3859  g_loss:2.4157
# epoch:1107  d_loss:0.5739  g_loss:1.9113
# epoch:1108  d_loss:0.5631  g_loss:1.6485
# epoch:1109  d_loss:0.4581  g_loss:2.3203
# epoch:1110  d_loss:0.7266  g_loss:1.9482
# epoch:1111  d_loss:0.5788  g_loss:1.7866
# epoch:1112  d_loss:0.6065  g_loss:1.5316
# epoch:1113  d_loss:0.4860  g_loss:1.9794
# epoch:1114  d_loss:0.4119  g_loss:1.8486
# epoch:1115  d_loss:0.4109  g_loss:1.8897
# epoch:1116  d_loss:0.5707  g_loss:1.7027
# epoch:1117  d_loss:0.3512  g_loss:1.8201
# epoch:1118  d_loss:0.5040  g_loss:1.6767
# epoch:1119  d_loss:0.4539  g_loss:1.6316
# epoch:1120  d_loss:0.6849  g_loss:1.3301
# epoch:1121  d_loss:0.5567  g_loss:1.5277
# epoch:1122  d_loss:0.3449  g_loss:1.6921
# epoch:1123  d_loss:0.5700  g_loss:1.8542
# epoch:1124  d_loss:0.5687  g_loss:1.4706
# epoch:1125  d_loss:0.4491  g_loss:1.4509
# epoch:1126  d_loss:0.3722  g_loss:1.5554
# epoch:1127  d_loss:0.3850  g_loss:2.3249
# epoch:1128  d_loss:0.3578  g_loss:2.1820
# epoch:1129  d_loss:0.3231  g_loss:2.0085
# epoch:1130  d_loss:0.4400  g_loss:1.5753
# epoch:1131  d_loss:0.3251  g_loss:1.7183
# epoch:1132  d_loss:0.2540  g_loss:2.0963
# epoch:1133  d_loss:0.3168  g_loss:2.1493
# epoch:1134  d_loss:0.3021  g_loss:2.7374
# epoch:1135  d_loss:0.4433  g_loss:2.3021
# epoch:1136  d_loss:0.2631  g_loss:2.7522
# epoch:1137  d_loss:0.2784  g_loss:2.0920
# epoch:1138  d_loss:0.2932  g_loss:1.9253
# epoch:1139  d_loss:0.3880  g_loss:2.2079
# epoch:1140  d_loss:0.3593  g_loss:2.2159
# epoch:1141  d_loss:0.3062  g_loss:2.2383
# epoch:1142  d_loss:0.2495  g_loss:2.5113
# epoch:1143  d_loss:0.2889  g_loss:3.2678
# epoch:1144  d_loss:0.4043  g_loss:2.3936
# epoch:1145  d_loss:0.3679  g_loss:1.9705
# epoch:1146  d_loss:0.3339  g_loss:1.9160
# epoch:1147  d_loss:0.3215  g_loss:2.5217
# epoch:1148  d_loss:0.3477  g_loss:2.5880
# epoch:1149  d_loss:0.6643  g_loss:1.9575
# epoch:1150  d_loss:0.4012  g_loss:2.1443
# epoch:1151  d_loss:0.3395  g_loss:1.8042
# epoch:1152  d_loss:0.4606  g_loss:1.8671
# epoch:1153  d_loss:0.5174  g_loss:1.8177
# epoch:1154  d_loss:0.5023  g_loss:1.5489
# epoch:1155  d_loss:0.5659  g_loss:2.0618
# epoch:1156  d_loss:0.5247  g_loss:2.3105
# epoch:1157  d_loss:0.6299  g_loss:1.9410
# epoch:1158  d_loss:0.7636  g_loss:1.8616
# epoch:1159  d_loss:0.5998  g_loss:1.2183
# epoch:1160  d_loss:0.6563  g_loss:1.3613
# epoch:1161  d_loss:0.4069  g_loss:1.7129
# epoch:1162  d_loss:0.4649  g_loss:1.6256
# epoch:1163  d_loss:0.5585  g_loss:1.6003
# epoch:1164  d_loss:0.5668  g_loss:1.6050
# epoch:1165  d_loss:0.5163  g_loss:1.8624
# epoch:1166  d_loss:0.5099  g_loss:1.8531
# epoch:1167  d_loss:0.6992  g_loss:1.3054
# epoch:1168  d_loss:0.4858  g_loss:1.2785
# epoch:1169  d_loss:0.4742  g_loss:1.6687
# epoch:1170  d_loss:0.4911  g_loss:2.0922
# epoch:1171  d_loss:0.3947  g_loss:1.9626
# epoch:1172  d_loss:0.4343  g_loss:1.6935
# epoch:1173  d_loss:0.3785  g_loss:1.9196
# epoch:1174  d_loss:0.3382  g_loss:1.8662
# epoch:1175  d_loss:0.3698  g_loss:1.9959
# epoch:1176  d_loss:0.4038  g_loss:2.0550
# epoch:1177  d_loss:0.3877  g_loss:1.9306
# epoch:1178  d_loss:0.3377  g_loss:1.9068
# ...
# epoch:2001  d_loss:0.3972  g_loss:1.5195
# epoch:2002  d_loss:0.5232  g_loss:2.0056
# epoch:2003  d_loss:0.4322  g_loss:2.0340
# epoch:2004  d_loss:0.3594  g_loss:2.0331
# epoch:2005  d_loss:0.4083  g_loss:2.0102
# epoch:2006  d_loss:0.5888  g_loss:1.3538
# epoch:2007  d_loss:0.3904  g_loss:1.4631
# epoch:2008  d_loss:0.4930  g_loss:1.5476
# epoch:2009  d_loss:0.4360  g_loss:1.5833
# epoch:2010  d_loss:0.3797  g_loss:1.7310
# epoch:2011  d_loss:0.3725  g_loss:1.5902
# epoch:2012  d_loss:0.4498  g_loss:1.7197
# epoch:2013  d_loss:0.4014  g_loss:1.7861
# epoch:2014  d_loss:0.4923  g_loss:1.5376
# epoch:2015  d_loss:0.4105  g_loss:1.8058
# epoch:2016  d_loss:0.5013  g_loss:1.7398
# epoch:2017  d_loss:0.4696  g_loss:1.6332
# epoch:2018  d_loss:0.4661  g_loss:1.3656
# epoch:2019  d_loss:0.5648  g_loss:1.5846
# epoch:2020  d_loss:0.5147  g_loss:1.5346
# epoch:2021  d_loss:0.4551  g_loss:1.8179
# epoch:2022  d_loss:0.3809  g_loss:1.6154
# epoch:2023  d_loss:0.5285  g_loss:1.8084
# epoch:2024  d_loss:0.5921  g_loss:1.7611
# epoch:2025  d_loss:0.7111  g_loss:1.5845
# epoch:2026  d_loss:0.5735  g_loss:1.3457
# epoch:2027  d_loss:0.4177  g_loss:1.4061
# epoch:2028  d_loss:0.4741  g_loss:1.6135
# epoch:2029  d_loss:0.4881  g_loss:1.7062
# epoch:2030  d_loss:0.5596  g_loss:1.7117
# epoch:2031  d_loss:0.5139  g_loss:1.5060
# epoch:2032  d_loss:0.7203  g_loss:1.5569
# epoch:2033  d_loss:0.5058  g_loss:1.6144
# epoch:2034  d_loss:0.4991  g_loss:1.3573
# epoch:2035  d_loss:0.5376  g_loss:1.3223
# epoch:2036  d_loss:0.4815  g_loss:1.3716
# epoch:2037  d_loss:0.5543  g_loss:1.5078
# epoch:2038  d_loss:0.5985  g_loss:1.2454
# epoch:2039  d_loss:0.5067  g_loss:1.5554
# epoch:2040  d_loss:0.4353  g_loss:2.2430
# epoch:2041  d_loss:0.4281  g_loss:1.8339
# epoch:2042  d_loss:0.5739  g_loss:1.8564
# epoch:2043  d_loss:0.6635  g_loss:1.5024
# epoch:2044  d_loss:0.5721  g_loss:1.2244
# epoch:2045  d_loss:0.5513  g_loss:1.2174
# epoch:2046  d_loss:0.4311  g_loss:1.4968
# epoch:2047  d_loss:0.4898  g_loss:1.6339
# epoch:2048  d_loss:0.3714  g_loss:1.8421
# epoch:2049  d_loss:0.5376  g_loss:1.7873
# epoch:2050  d_loss:0.5023  g_loss:1.5696
# epoch:2051  d_loss:0.5318  g_loss:1.3813
# epoch:2052  d_loss:0.5170  g_loss:1.5387
# epoch:2053  d_loss:0.5683  g_loss:1.4048
# epoch:2054  d_loss:0.5069  g_loss:1.6225
# epoch:2055  d_loss:0.4686  g_loss:1.5873
# epoch:2056  d_loss:0.6731  g_loss:1.7064
# epoch:2057  d_loss:0.5320  g_loss:1.6171
# epoch:2058  d_loss:0.5148  g_loss:1.7500
# epoch:2059  d_loss:0.6169  g_loss:1.3001
# epoch:2060  d_loss:0.7295  g_loss:1.2188
# epoch:2061  d_loss:0.5557  g_loss:1.5416
# epoch:2062  d_loss:0.4725  g_loss:1.2917
# epoch:2063  d_loss:0.4952  g_loss:1.4365
# epoch:2064  d_loss:0.4751  g_loss:1.6607
# epoch:2065  d_loss:0.4776  g_loss:1.8530
# epoch:2066  d_loss:0.5050  g_loss:1.4923
# epoch:2067  d_loss:0.5461  g_loss:1.2393
# epoch:2068  d_loss:0.4401  g_loss:1.3287
# epoch:2069  d_loss:0.4710  g_loss:1.1026
# epoch:2070  d_loss:0.5335  g_loss:1.2322
# epoch:2071  d_loss:0.5078  g_loss:1.5548
# epoch:2072  d_loss:0.4589  g_loss:1.7131
# epoch:2073  d_loss:0.5127  g_loss:1.6028
# epoch:2074  d_loss:0.4053  g_loss:1.8178
# epoch:2075  d_loss:0.5778  g_loss:1.5270
# epoch:2076  d_loss:0.3911  g_loss:1.5305
# epoch:2077  d_loss:0.4749  g_loss:1.3751
# epoch:2078  d_loss:0.4733  g_loss:1.7237
# epoch:2079  d_loss:0.4364  g_loss:1.9272
# epoch:2080  d_loss:0.5831  g_loss:1.6732
# epoch:2081  d_loss:0.5558  g_loss:1.4416
# epoch:2082  d_loss:0.4220  g_loss:1.6052
# epoch:2083  d_loss:0.5082  g_loss:1.3598
# epoch:2084  d_loss:0.4719  g_loss:1.4804
# epoch:2085  d_loss:0.5151  g_loss:1.6244
# epoch:2086  d_loss:0.5869  g_loss:1.4991
# epoch:2087  d_loss:0.5353  g_loss:1.7226
# epoch:2088  d_loss:0.6777  g_loss:1.3903
# epoch:2089  d_loss:0.5279  g_loss:1.3571
# epoch:2090  d_loss:0.4996  g_loss:1.2838
# epoch:2091  d_loss:0.5696  g_loss:1.1737
# epoch:2092  d_loss:0.4577  g_loss:1.5123
# epoch:2093  d_loss:0.5480  g_loss:1.5377
# epoch:2094  d_loss:0.5366  g_loss:1.5038
# epoch:2095  d_loss:0.4779  g_loss:1.6124
# epoch:2096  d_loss:0.4692  g_loss:1.5685
# epoch:2097  d_loss:0.6144  g_loss:1.3674
# epoch:2098  d_loss:0.5102  g_loss:1.4021
# epoch:2099  d_loss:0.4761  g_loss:1.4173
# epoch:2100  d_loss:0.6059  g_loss:1.3983
# epoch:2101  d_loss:0.5075  g_loss:1.8552
# epoch:2102  d_loss:0.4456  g_loss:1.5687
# epoch:2103  d_loss:0.4144  g_loss:1.7989
# epoch:2104  d_loss:0.5349  g_loss:1.4719
# epoch:2105  d_loss:0.5555  g_loss:1.8781
# epoch:2106  d_loss:0.5934  g_loss:1.3315
# epoch:2107  d_loss:0.6745  g_loss:1.1676
# epoch:2108  d_loss:0.4399  g_loss:1.3039
# epoch:2109  d_loss:0.6117  g_loss:1.1887
# epoch:2110  d_loss:0.5949  g_loss:1.3292
# epoch:2111  d_loss:0.5596  g_loss:1.6229
# epoch:2112  d_loss:0.6145  g_loss:1.5583
# epoch:2113  d_loss:0.6177  g_loss:1.3800
# epoch:2114  d_loss:0.6094  g_loss:1.3625
# epoch:2115  d_loss:0.5075  g_loss:1.4064
# epoch:2116  d_loss:0.5695  g_loss:1.4827
# epoch:2117  d_loss:0.4762  g_loss:1.7338
# epoch:2118  d_loss:0.6103  g_loss:1.2945
# epoch:2119  d_loss:0.5205  g_loss:1.3404
# epoch:2120  d_loss:0.7037  g_loss:1.0861
# epoch:2121  d_loss:0.5098  g_loss:1.2037
# epoch:2122  d_loss:0.4866  g_loss:1.5084
# epoch:2123  d_loss:0.5344  g_loss:1.3805
# epoch:2124  d_loss:0.6691  g_loss:1.4281
# epoch:2125  d_loss:0.4253  g_loss:1.7081
# epoch:2126  d_loss:0.5790  g_loss:1.4003
# epoch:2127  d_loss:0.4751  g_loss:1.8010
# epoch:2128  d_loss:0.4688  g_loss:2.0241
# epoch:2129  d_loss:0.4862  g_loss:1.7258
# epoch:2130  d_loss:0.3764  g_loss:1.5275
# epoch:2131  d_loss:0.5469  g_loss:1.3517
# epoch:2132  d_loss:0.5306  g_loss:1.5125
# epoch:2133  d_loss:0.4495  g_loss:1.5384
# epoch:2134  d_loss:0.4723  g_loss:1.5992
# epoch:2135  d_loss:0.4903  g_loss:1.5957
# epoch:2136  d_loss:0.5055  g_loss:1.8696
# epoch:2137  d_loss:0.4683  g_loss:1.7675
# epoch:2138  d_loss:0.5534  g_loss:1.5326
# epoch:2139  d_loss:0.5910  g_loss:1.4366
# epoch:2140  d_loss:0.4439  g_loss:1.5617
# epoch:2141  d_loss:0.3738  g_loss:1.7643
# epoch:2142  d_loss:0.4484  g_loss:1.5335
# epoch:2143  d_loss:0.4598  g_loss:1.4958
# epoch:2144  d_loss:0.4046  g_loss:1.3476
# epoch:2145  d_loss:0.5755  g_loss:1.0485
# epoch:2146  d_loss:0.5563  g_loss:1.5540
# epoch:2147  d_loss:0.5210  g_loss:1.4653
# epoch:2148  d_loss:0.5230  g_loss:1.7444
# epoch:2149  d_loss:0.6253  g_loss:1.5682
# epoch:2150  d_loss:0.6628  g_loss:1.6133
# epoch:2151  d_loss:0.5431  g_loss:1.6759
# epoch:2152  d_loss:0.6284  g_loss:1.5352
# epoch:2153  d_loss:0.6010  g_loss:1.3716
# epoch:2154  d_loss:0.6097  g_loss:1.4235
# epoch:2155  d_loss:0.5825  g_loss:1.3622
# epoch:2156  d_loss:0.4373  g_loss:1.6568
# epoch:2157  d_loss:0.5052  g_loss:1.6356
# epoch:2158  d_loss:0.5229  g_loss:1.6295
# epoch:2159  d_loss:0.5741  g_loss:1.5261
# epoch:2160  d_loss:0.4313  g_loss:1.3119
# epoch:2161  d_loss:0.6977  g_loss:1.0894
# epoch:2162  d_loss:0.4797  g_loss:1.1135
# epoch:2163  d_loss:0.4948  g_loss:1.5042
# epoch:2164  d_loss:0.5436  g_loss:1.3978
# epoch:2165  d_loss:0.3927  g_loss:1.5345
# epoch:2166  d_loss:0.6271  g_loss:1.2004
# epoch:2167  d_loss:0.5561  g_loss:1.2142
# epoch:2168  d_loss:0.4289  g_loss:1.4880
# epoch:2169  d_loss:0.4184  g_loss:1.3542
# epoch:2170  d_loss:0.5796  g_loss:1.3633
# epoch:2171  d_loss:0.4419  g_loss:1.6308
# epoch:2172  d_loss:0.4864  g_loss:1.7835
# epoch:2173  d_loss:0.4879  g_loss:1.6314
# epoch:2174  d_loss:0.4839  g_loss:1.5804
# epoch:2175  d_loss:0.5416  g_loss:1.4485
# epoch:2176  d_loss:0.4868  g_loss:1.3380
# epoch:2177  d_loss:0.4754  g_loss:1.7625
# epoch:2178  d_loss:0.4720  g_loss:1.9411
# epoch:2179  d_loss:0.3946  g_loss:2.1173
# epoch:2180  d_loss:0.5630  g_loss:2.1539
# epoch:2181  d_loss:0.5130  g_loss:1.7201
# epoch:2182  d_loss:0.4886  g_loss:1.5202
# epoch:2183  d_loss:0.4216  g_loss:1.2659
# epoch:2184  d_loss:0.6490  g_loss:1.1124
# epoch:2185  d_loss:0.4837  g_loss:1.4588
# epoch:2186  d_loss:0.3911  g_loss:1.8247
# epoch:2187  d_loss:0.5358  g_loss:1.6316
# epoch:2188  d_loss:0.7421  g_loss:1.7169
# epoch:2189  d_loss:0.5242  g_loss:1.7250
# epoch:2190  d_loss:0.5587  g_loss:1.5661
# epoch:2191  d_loss:0.6318  g_loss:1.1523
# epoch:2192  d_loss:0.3434  g_loss:1.6492
# epoch:2193  d_loss:0.4556  g_loss:1.9145
# epoch:2194  d_loss:0.5897  g_loss:1.8179
# epoch:2195  d_loss:0.5630  g_loss:1.4470
# epoch:2196  d_loss:0.4668  g_loss:1.6911
# epoch:2197  d_loss:0.5751  g_loss:1.5407
# epoch:2198  d_loss:0.4640  g_loss:1.3499
# epoch:2199  d_loss:0.4619  g_loss:1.3653
# epoch:2200  d_loss:0.5680  g_loss:1.5905
# epoch:2201  d_loss:0.4154  g_loss:2.1825
# epoch:2202  d_loss:0.4363  g_loss:1.8933
# epoch:2203  d_loss:0.3442  g_loss:1.6884
# epoch:2204  d_loss:0.5883  g_loss:1.4852
# epoch:2205  d_loss:0.5277  g_loss:1.3960
# epoch:2206  d_loss:0.4431  g_loss:1.4753
# epoch:2207  d_loss:0.5546  g_loss:2.0962
# epoch:2208  d_loss:0.4179  g_loss:2.0833
# epoch:2209  d_loss:0.5426  g_loss:1.6890
# epoch:2210  d_loss:0.5706  g_loss:1.5702
# epoch:2211  d_loss:0.5946  g_loss:1.3549
# epoch:2212  d_loss:0.5148  g_loss:1.2580
# epoch:2213  d_loss:0.5833  g_loss:1.1725
# epoch:2214  d_loss:0.3819  g_loss:1.4146
# epoch:2215  d_loss:0.5702  g_loss:1.7377
# epoch:2216  d_loss:0.4565  g_loss:1.9135
# epoch:2217  d_loss:0.5258  g_loss:1.9052
# epoch:2218  d_loss:0.5139  g_loss:1.8921
# epoch:2219  d_loss:0.5324  g_loss:1.6074
# epoch:2220  d_loss:0.4157  g_loss:1.5325
# epoch:2221  d_loss:0.5843  g_loss:1.3990
# epoch:2222  d_loss:0.5605  g_loss:1.4305
# epoch:2223  d_loss:0.5790  g_loss:1.5314
# epoch:2224  d_loss:0.5507  g_loss:1.9949
# epoch:2225  d_loss:0.6430  g_loss:1.6290
# epoch:2226  d_loss:0.4879  g_loss:1.4503
# epoch:2227  d_loss:0.4465  g_loss:1.3685
# epoch:2228  d_loss:0.5722  g_loss:1.2471
# epoch:2229  d_loss:0.5358  g_loss:1.3094
# epoch:2230  d_loss:0.5625  g_loss:1.2659
# epoch:2231  d_loss:0.5487  g_loss:1.3476
# epoch:2232  d_loss:0.5043  g_loss:1.8977
# epoch:2233  d_loss:0.5134  g_loss:1.4619
# epoch:2234  d_loss:0.5919  g_loss:1.4339
# epoch:2235  d_loss:0.4590  g_loss:1.6088
# epoch:2236  d_loss:0.3873  g_loss:1.6677
# epoch:2237  d_loss:0.4003  g_loss:1.2904
# epoch:2238  d_loss:0.5341  g_loss:1.3950
# epoch:2239  d_loss:0.5195  g_loss:1.5160
# epoch:2240  d_loss:0.4978  g_loss:1.5875
# epoch:2241  d_loss:0.4178  g_loss:1.6958
# epoch:2242  d_loss:0.6003  g_loss:1.2476
# epoch:2243  d_loss:0.5032  g_loss:1.4384
# epoch:2244  d_loss:0.5266  g_loss:1.4846
# epoch:2245  d_loss:0.5235  g_loss:1.5043
# epoch:2246  d_loss:0.4455  g_loss:1.5094
# epoch:2247  d_loss:0.6179  g_loss:1.4584
# epoch:2248  d_loss:0.3508  g_loss:2.1461
# epoch:2249  d_loss:0.4942  g_loss:1.8349
# epoch:2250  d_loss:0.5623  g_loss:1.6443
# epoch:2251  d_loss:0.3258  g_loss:1.6664
# epoch:2252  d_loss:0.5562  g_loss:1.5073
# epoch:2253  d_loss:0.4686  g_loss:1.4395
# epoch:2254  d_loss:0.4796  g_loss:1.5879
# epoch:2255  d_loss:0.3955  g_loss:1.6590
# epoch:2256  d_loss:0.4281  g_loss:1.8668
# epoch:2257  d_loss:0.3820  g_loss:1.8353
# epoch:2258  d_loss:0.5315  g_loss:1.4931
# epoch:2259  d_loss:0.5516  g_loss:1.3989
# epoch:2260  d_loss:0.4702  g_loss:1.4218
# epoch:2261  d_loss:0.5883  g_loss:1.6626
# epoch:2262  d_loss:0.4539  g_loss:1.2913
# epoch:2263  d_loss:0.5225  g_loss:1.7520
# epoch:2264  d_loss:0.5679  g_loss:1.5557
# epoch:2265  d_loss:0.4694  g_loss:1.5155
# epoch:2266  d_loss:0.3964  g_loss:1.6883
# epoch:2267  d_loss:0.3954  g_loss:1.5875
# epoch:2268  d_loss:0.4733  g_loss:1.3462
# epoch:2269  d_loss:0.3844  g_loss:1.5543
# epoch:2270  d_loss:0.5697  g_loss:1.5540
# epoch:2271  d_loss:0.4362  g_loss:1.7819
# epoch:2272  d_loss:0.5746  g_loss:1.5923
# epoch:2273  d_loss:0.4862  g_loss:1.4918
# epoch:2274  d_loss:0.6301  g_loss:1.5281
# epoch:2275  d_loss:0.5410  g_loss:1.4465
# epoch:2276  d_loss:0.5345  g_loss:1.5424
# epoch:2277  d_loss:0.4216  g_loss:1.5199
# epoch:2278  d_loss:0.5314  g_loss:1.7750
# epoch:2279  d_loss:0.4771  g_loss:1.4327
# epoch:2280  d_loss:0.5069  g_loss:1.5401
# epoch:2281  d_loss:0.6174  g_loss:1.3652
# epoch:2282  d_loss:0.5133  g_loss:1.3564
# epoch:2283  d_loss:0.6370  g_loss:1.2284
# epoch:2284  d_loss:0.5565  g_loss:1.6107
# epoch:2285  d_loss:0.6412  g_loss:1.5337
# epoch:2286  d_loss:0.5162  g_loss:1.6122
# epoch:2287  d_loss:0.4117  g_loss:1.3610
# epoch:2288  d_loss:0.5033  g_loss:1.3753
# epoch:2289  d_loss:0.5691  g_loss:1.5788
# epoch:2290  d_loss:0.5937  g_loss:1.4430
# epoch:2291  d_loss:0.4770  g_loss:1.7335
# epoch:2292  d_loss:0.5600  g_loss:1.3010
# epoch:2293  d_loss:0.4476  g_loss:1.9500
# epoch:2294  d_loss:0.5409  g_loss:1.5811
# epoch:2295  d_loss:0.7182  g_loss:1.6401
# epoch:2296  d_loss:0.5552  g_loss:1.6790
# epoch:2297  d_loss:0.5725  g_loss:1.7047
# epoch:2298  d_loss:0.5536  g_loss:1.5921
# epoch:2299  d_loss:0.5565  g_loss:1.4208
# epoch:2300  d_loss:0.5639  g_loss:1.6357
# epoch:2301  d_loss:0.4574  g_loss:1.4751
# epoch:2302  d_loss:0.5502  g_loss:1.5417
# epoch:2303  d_loss:0.5034  g_loss:1.7472
# epoch:2304  d_loss:0.4155  g_loss:1.7461
# epoch:2305  d_loss:0.5888  g_loss:1.3223
# epoch:2306  d_loss:0.6937  g_loss:1.0590
# epoch:2307  d_loss:0.5393  g_loss:1.5075
# epoch:2308  d_loss:0.6073  g_loss:1.8986
# epoch:2309  d_loss:0.5496  g_loss:1.5812
# epoch:2310  d_loss:0.5007  g_loss:1.4218
# epoch:2311  d_loss:0.5653  g_loss:1.4350
# epoch:2312  d_loss:0.5674  g_loss:1.4437
# epoch:2313  d_loss:0.4857  g_loss:1.2236
# epoch:2314  d_loss:0.4983  g_loss:1.5552
# epoch:2315  d_loss:0.5832  g_loss:1.2297
# epoch:2316  d_loss:0.5308  g_loss:1.4590
# epoch:2317  d_loss:0.4553  g_loss:1.8976
# epoch:2318  d_loss:0.4723  g_loss:1.6863
# epoch:2319  d_loss:0.3701  g_loss:1.8267
# epoch:2320  d_loss:0.4918  g_loss:1.6998
# epoch:2321  d_loss:0.4727  g_loss:1.7028
# epoch:2322  d_loss:0.5642  g_loss:1.7012
# epoch:2323  d_loss:0.5273  g_loss:1.4026
# epoch:2324  d_loss:0.4018  g_loss:1.4824
# epoch:2325  d_loss:0.5993  g_loss:1.3265
# epoch:2326  d_loss:0.5772  g_loss:1.3851
# epoch:2327  d_loss:0.6183  g_loss:1.5329
# epoch:2328  d_loss:0.5802  g_loss:1.7693
# epoch:2329  d_loss:0.4444  g_loss:1.5621
# epoch:2330  d_loss:0.5932  g_loss:1.5471
# epoch:2331  d_loss:0.6232  g_loss:1.6689
# epoch:2332  d_loss:0.4954  g_loss:1.3563
# epoch:2333  d_loss:0.4970  g_loss:1.4165
# epoch:2334  d_loss:0.3895  g_loss:1.9542
# epoch:2335  d_loss:0.5453  g_loss:1.4971
# epoch:2336  d_loss:0.4829  g_loss:1.8551
# epoch:2337  d_loss:0.6286  g_loss:1.4647
# epoch:2338  d_loss:0.5352  g_loss:1.1580
# epoch:2339  d_loss:0.4406  g_loss:1.6355
# epoch:2340  d_loss:0.4281  g_loss:1.4080
# epoch:2341  d_loss:0.4177  g_loss:1.5968
# epoch:2342  d_loss:0.4598  g_loss:1.9119
# epoch:2343  d_loss:0.5698  g_loss:1.5989
# epoch:2344  d_loss:0.5001  g_loss:1.5033
# epoch:2345  d_loss:0.5468  g_loss:1.2984
# epoch:2346  d_loss:0.4319  g_loss:1.7194
# epoch:2347  d_loss:0.5267  g_loss:1.3696
# epoch:2348  d_loss:0.6401  g_loss:1.4168
# epoch:2349  d_loss:0.5441  g_loss:1.5758
# epoch:2350  d_loss:0.4591  g_loss:1.2370
# epoch:2351  d_loss:0.4987  g_loss:1.2327
# epoch:2352  d_loss:0.5367  g_loss:1.3393
# epoch:2353  d_loss:0.4731  g_loss:1.3367
# epoch:2354  d_loss:0.4327  g_loss:1.4063
# epoch:2355  d_loss:0.5456  g_loss:1.4238
# epoch:2356  d_loss:0.5045  g_loss:1.4795
# epoch:2357  d_loss:0.4634  g_loss:1.8652
# epoch:2358  d_loss:0.6089  g_loss:1.3687
# epoch:2359  d_loss:0.4743  g_loss:1.5476
# epoch:2360  d_loss:0.5004  g_loss:1.5004
# epoch:2361  d_loss:0.4926  g_loss:1.7372
# epoch:2362  d_loss:0.6308  g_loss:1.7283
# epoch:2363  d_loss:0.5102  g_loss:1.0368
# epoch:2364  d_loss:0.6275  g_loss:1.4034
# epoch:2365  d_loss:0.5430  g_loss:1.3430
# epoch:2366  d_loss:0.4632  g_loss:1.4132
# epoch:2367  d_loss:0.5260  g_loss:1.4032
# epoch:2368  d_loss:0.5003  g_loss:1.6503
# epoch:2369  d_loss:0.5558  g_loss:1.5258
# epoch:2370  d_loss:0.4679  g_loss:1.6903
# epoch:2371  d_loss:0.5204  g_loss:1.6997
# epoch:2372  d_loss:0.4839  g_loss:1.2733
# epoch:2373  d_loss:0.5994  g_loss:1.8064
# epoch:2374  d_loss:0.4252  g_loss:2.1975
# epoch:2375  d_loss:0.4662  g_loss:1.6233
# epoch:2376  d_loss:0.6335  g_loss:1.1378
# epoch:2377  d_loss:0.3694  g_loss:1.5978
# epoch:2378  d_loss:0.5229  g_loss:1.4602
# epoch:2379  d_loss:0.4309  g_loss:1.3440
# epoch:2380  d_loss:0.4088  g_loss:1.6585
# epoch:2381  d_loss:0.4817  g_loss:1.5635
# epoch:2382  d_loss:0.4406  g_loss:1.5080
# epoch:2383  d_loss:0.4597  g_loss:1.7258
# epoch:2384  d_loss:0.5050  g_loss:1.7453
# epoch:2385  d_loss:0.4468  g_loss:1.6696
# epoch:2386  d_loss:0.4945  g_loss:1.4209
# epoch:2387  d_loss:0.5019  g_loss:1.4201
# epoch:2388  d_loss:0.5070  g_loss:1.3406
# epoch:2389  d_loss:0.4190  g_loss:1.5902
# epoch:2390  d_loss:0.5079  g_loss:1.5045
